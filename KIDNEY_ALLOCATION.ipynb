# %% [markdown]
# <a href="https://colab.research.google.com/github/SriJhanyaa/OIBSIP--Java-Programming-/blob/main/KIDNEY_ALLOCATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA AUDITING**

# %%
# !pip install lifelines
# Out:
# Collecting lifelines
#   Downloading lifelines-0.27.8-py3-none-any.whl (350 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.7/350.7 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from lifelines) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from lifelines) (1.11.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from lifelines) (1.5.3)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from lifelines) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.10/dist-packages (from lifelines) (1.6.2)
# Collecting autograd-gamma>=0.3 (from lifelines)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines)
#   Downloading formulaic-0.6.6-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd>=1.5->lifelines) (0.18.3)
# Collecting astor>=0.8 (from formulaic>=0.2.2->lifelines)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines)
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines) (4.5.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->lifelines) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.16.0)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=c5d05149e72d35be1265417ce46f158970cdafaa7410721d2a8b28e3bcd836ca
#   Stored in directory: /root/.cache/pip/wheels/25/cc/e0/ef2969164144c899fedb22b338f6703e2b9cf46eeebf254991
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, astor, autograd-gamma, formulaic, lifelines
# Successfully installed astor-0.8.1 autograd-gamma-0.5.0 formulaic-0.6.6 interface-meta-1.3.0 lifelines-0.27.8

# %%
import pandas as pd
#for data analysis and preprocessing
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

# %%
import seaborn as sns
sns.set(style='whitegrid')
# %matplotlib inline
#Survival Analysis
from lifelines import KaplanMeierFitter,CoxPHFitter
#---------------------------------------------------------------------

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency, f_oneway, kruskal
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %% [markdown]
# EXAMINING **THE** DATASET

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_pathbar.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_uirevision.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_branchvalues.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_textinfo.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_parentssrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_opacity.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_uid.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_hoverlabel.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_textsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_customdatasrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_texttemplate.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_hovertemplate.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_stream.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_textposition.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_hoverinfosrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_maxdepth.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_idssrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_count.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_leaf.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_outsidetextfont.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_marker.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_text.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_texttemplatesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_visible.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_ids.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_hovertextsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_textfont.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/__pycache__/_legendrank.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/_token.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/_maxpoints.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/__pycache__/_token.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/__pycache__/_maxpoints.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/stream/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/leaf/_opacity.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/leaf/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/leaf/__pycache__/_opacity.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/leaf/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_familysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_sizesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/_colorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_familysrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_sizesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/textfont/__pycache__/_colorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/_orientation.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/_flip.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/_pad.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/__pycache__/_pad.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/__pycache__/_flip.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/tiling/__pycache__/_orientation.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_familysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_sizesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/_colorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_familysrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_sizesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/insidetextfont/__pycache__/_colorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/_textfont.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/_edgeshape.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/_side.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/_visible.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/_thickness.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/_edgeshape.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/_thickness.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/_side.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/_visible.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/__pycache__/_textfont.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_familysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_sizesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/_colorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_familysrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_sizesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/pathbar/textfont/__pycache__/_colorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/root/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/root/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/root/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/root/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_familysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_sizesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/_colorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_familysrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_sizesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/outsidetextfont/__pycache__/_colorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/_x.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/_row.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/_y.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/_column.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__pycache__/_row.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__pycache__/_column.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__pycache__/_y.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/domain/__pycache__/_x.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/_text.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/_font.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/__pycache__/_font.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/__pycache__/_text.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/legendgrouptitle/font/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_pattern.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_coloraxis.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_cauto.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_autocolorscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_showscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_colors.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_colorscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_colorssrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_cmid.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_reversescale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_line.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_colorbar.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_cmin.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/_cmax.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_lenmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_x.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tick0.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickformatstopdefaults.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_orientation.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickformatstops.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickvalssrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_thicknessmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_showticklabels.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_outlinewidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_separatethousands.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticklen.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickprefix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticktext.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_dtick.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_xanchor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_showexponent.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticklabelposition.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_showtickprefix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_outlinecolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticktextsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickfont.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_bordercolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_nticks.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickwidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickvals.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_minexponent.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_showticksuffix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_len.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticks.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ypad.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticksuffix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_exponentformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticklabelstep.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_title.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_borderwidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_yanchor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickangle.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_ticklabeloverflow.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_labelalias.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_xref.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_xpad.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_thickness.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_yref.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_tickmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_y.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/_bgcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_yref.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticks.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_showexponent.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticklabelposition.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_yanchor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_showticksuffix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_labelalias.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticklen.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_outlinewidth.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickmode.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_outlinecolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickfont.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_thickness.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticksuffix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickformatstopdefaults.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_len.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickformatstops.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_separatethousands.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_dtick.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_xpad.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickvalssrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_bgcolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickprefix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticktextsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_title.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickformat.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_lenmode.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_showtickprefix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticklabelstep.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tick0.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickwidth.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_exponentformat.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_thicknessmode.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_borderwidth.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ypad.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticktext.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_showticklabels.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_ticklabeloverflow.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickcolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickangle.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_orientation.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_tickvals.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_bordercolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_y.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_nticks.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_xanchor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_x.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_xref.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/__pycache__/_minexponent.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/_text.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/_side.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/_font.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/__pycache__/_font.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/__pycache__/_side.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/__pycache__/_text.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/title/font/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/_value.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/_dtickrange.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/_name.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/_templateitemname.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/_enabled.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/_templateitemname.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/_enabled.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/_dtickrange.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/_name.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/colorbar/tickformatstop/__pycache__/_value.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_coloraxis.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_colorssrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_colorbar.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_cauto.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_colorscale.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_reversescale.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_autocolorscale.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_cmin.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_showscale.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_colors.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_cmid.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_pattern.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_cmax.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/__pycache__/_line.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/_colorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/_width.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/_widthsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__pycache__/_widthsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__pycache__/_width.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/line/__pycache__/_colorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_fgcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_fgcolorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_soliditysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_solidity.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_shape.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_bgcolorsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_shapesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_fgopacity.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_sizesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_fillmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/_bgcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_solidity.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_bgcolorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_fgcolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_fillmode.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_bgcolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_shapesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_shape.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_fgopacity.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_fgcolorsrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_sizesrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/icicle/marker/pattern/__pycache__/_soliditysrc.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_contour.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_x.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hoverinfo.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_stream.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_valuehoverformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_coloraxis.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_zhoverformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_cauto.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_ids.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_lighting.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_value.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_surface.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_isomax.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_text.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_autocolorscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_xsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_z.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_yhoverformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_lightposition.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_valuesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_opacity.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_showscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_legendgroup.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_idssrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_uirevision.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_scene.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hoverinfosrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_colorscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_name.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_opacityscale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_customdata.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hovertext.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_caps.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_cmid.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_legendrank.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_uid.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_reversescale.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_zsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_legend.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_meta.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_showlegend.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_legendgrouptitle.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_visible.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hovertemplatesrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_metasrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_colorbar.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hovertextsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_ysrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_customdatasrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_cmin.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_flatshading.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_slices.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_spaceframe.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hoverlabel.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_isomin.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_textsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_y.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_xhoverformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_legendwidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_hovertemplate.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/_cmax.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_lenmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_x.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tick0.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickformatstopdefaults.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_orientation.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickformatstops.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickvalssrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_thicknessmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_showticklabels.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_outlinewidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_separatethousands.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticklen.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickprefix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticktext.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_dtick.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_xanchor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_showexponent.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticklabelposition.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_showtickprefix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_outlinecolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticktextsrc.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickfont.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_bordercolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_nticks.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickwidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickvals.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_minexponent.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_showticksuffix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_len.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticks.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ypad.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticksuffix.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_exponentformat.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticklabelstep.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_title.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_borderwidth.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_yanchor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickangle.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_ticklabeloverflow.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_labelalias.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_xref.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_xpad.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_thickness.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_yref.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_tickmode.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_y.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/_bgcolor.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/_color.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/__init__.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/_size.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/_family.py
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/__pycache__/_family.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/__pycache__/_color.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/__pycache__/__init__.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/tickfont/__pycache__/_size.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_yref.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_ticks.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_showexponent.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_ticklabelposition.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_yanchor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_showticksuffix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_labelalias.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_ticklen.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_outlinewidth.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_tickmode.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_outlinecolor.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_tickfont.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_thickness.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_ticksuffix.cpython-310.pyc
# /usr/local/lib/python3.10/dist-packages/plotly/validators/volume/colorbar/__pycache__/_tickformatstopdefaults.cpython-310.pyc
# ...
# /python-apt/po/eo.po
# /python-apt/po/zh_TW.po
# /python-apt/po/pl.po
# /python-apt/po/ka.po
# /python-apt/po/pt.po
# /python-apt/po/csb.po
# /python-apt/po/cs.po
# /python-apt/po/he.po
# /python-apt/po/bn.po
# /python-apt/po/ja.po
# /python-apt/po/es.po
# /python-apt/po/lv.po
# /python-apt/po/hu.po
# /python-apt/po/bg.po
# /python-apt/po/lt.po
# /python-apt/po/fr.po
# /python-apt/po/tr.po
# /python-apt/po/be.po
# /python-apt/po/ku.po
# /python-apt/po/de.po
# /python-apt/po/nl.po
# /python-apt/po/ko.po
# /python-apt/po/zh_CN.po
# /python-apt/po/ne.po
# /python-apt/po/ro.po
# /python-apt/po/da.po
# /python-apt/po/en_AU.po
# /python-apt/po/ca.po
# /python-apt/po/mk.po
# /python-apt/po/sl.po
# /python-apt/po/sq.po
# /python-apt/po/sv.po
# /python-apt/po/en_CA.po
# /python-apt/po/el.po
# /python-apt/po/sk.po
# /python-apt/po/pt_BR.po
# /python-apt/po/ru.po
# /python-apt/po/fi.po
# /python-apt/po/oc.po
# /python-apt/po/it.po
# /python-apt/po/tl.po
# /python-apt/po/gl.po
# /python-apt/po/th.po
# /python-apt/po/uk.po
# /python-apt/po/nb.po
# /python-apt/po/sr.po
# /python-apt/po/POTFILES.in
# /python-apt/po/python-apt.pot
# /python-apt/po/zh_HK.po
# /python-apt/po/vi.po
# /python-apt/debian/python-apt-dev.maintscript
# /python-apt/debian/python-apt-doc.examples
# /python-apt/debian/control
# /python-apt/debian/gbp.conf
# /python-apt/debian/python-apt-dev.install
# /python-apt/debian/changelog
# /python-apt/debian/python-apt-doc.doc-base
# /python-apt/debian/copyright
# /python-apt/debian/rules
# /python-apt/debian/python3-apt.lintian-overrides
# /python-apt/debian/python-apt-doc.docs
# /python-apt/debian/python-apt-dev.examples
# /python-apt/debian/python-apt-doc.maintscript
# /python-apt/debian/tests/control
# /python-apt/debian/tests/run-tests
# /python-apt/debian/source/format
# /python-apt/tests/test_hashsums.py
# /python-apt/tests/fakeroot-apt-key
# /python-apt/tests/test_install_progress_exec.py
# /python-apt/tests/test_sourcerecords.py
# /python-apt/tests/helper_install_progress_run.py
# /python-apt/tests/test_hashes.py
# /python-apt/tests/test_debfile_multiarch.py
# /python-apt/tests/test_policy.py
# /python-apt/tests/test_cache_invocation.py
# /python-apt/tests/test_lp659438.py
# /python-apt/tests/test_pep484.py
# /python-apt/tests/test_size_to_str.py
# /python-apt/tests/__init__.py
# /python-apt/tests/test_large_file.py
# /python-apt/tests/test_auth.py
# /python-apt/tests/testcommon.py
# /python-apt/tests/test_debfile.py
# /python-apt/tests/test_group.py
# /python-apt/tests/test_lfs.py
# /python-apt/tests/test_tagfile.py
# /python-apt/tests/test_aptsources_ports.py
# /python-apt/tests/test_utils.py
# /python-apt/tests/test_pyflakes.py
# /python-apt/tests/test_paths.py
# /python-apt/tests/test_all.py
# /python-apt/tests/test_aptsources.py
# /python-apt/tests/test_cve_2020_27351.py
# /python-apt/tests/test_configuration.py
# /python-apt/tests/test_progress.py
# /python-apt/tests/test_deps.py
# /python-apt/tests/testmanual_pycodestyle.py
# /python-apt/tests/test_apt_cache.py
# /python-apt/tests/test_signed_usable.py
# /python-apt/tests/old/pkgrecords.py
# /python-apt/tests/old/test_enhances.py
# /python-apt/tests/old/pkgsrcrecords.py
# /python-apt/tests/old/apt-test.py
# /python-apt/tests/old/__init__.py
# /python-apt/tests/old/cache.py
# /python-apt/tests/old/refcount.py
# /python-apt/tests/old/lock.py
# /python-apt/tests/old/depcache.py
# /python-apt/tests/old/pkgproblemresolver.py
# /python-apt/tests/old/memleak.py
# /python-apt/tests/data/fake-packages/Packages.gz
# /python-apt/tests/data/fake-packages/Packages
# /python-apt/tests/data/aptsources_ports/sources.list
# /python-apt/tests/data/test-provides/var/lib/dpkg/status
# /python-apt/tests/data/test-provides/var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_oneiric_main_binary-i386_Packages
# /python-apt/tests/data/test-provides/etc/apt/sources.list
# /python-apt/tests/data/test-repo/Packages.gz
# /python-apt/tests/data/aptsources/sources.list.testDistribution
# /python-apt/tests/data/aptsources/sources.list.testDuplication
# /python-apt/tests/data/aptsources/lsb-release
# /python-apt/tests/data/aptsources/os-release
# /python-apt/tests/data/aptsources/sources.list
# /python-apt/tests/data/test-signed-usable-repo/key.gpg.base64
# /python-apt/tests/data/test-signed-usable-repo/seckey.asc
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/signed/Release.gpg
# /python-apt/tests/data/test-signed-usable-repo/signed/Release
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-not-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/signed/Sources
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/signed/Packages
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-not-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-unusable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-not-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Release
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Sources
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Packages
# /python-apt/tests/data/misc/foo_Release
# /python-apt/tests/data/tagfile/history.1.log.gz
# /python-apt/tests/data/tagfile/history.log
# /python-apt/tests/data/hashsums/hashsum_test.data
# /python-apt/tests/data/hashsums/hashsum_test_with_zero.data
# /python-apt/tests/data/test_debs/gdebi-test11.deb
# /python-apt/tests/data/test_debs/gdebi-test6.deb
# /python-apt/tests/data/test_debs/large-package-content_1.0_all.deb
# /python-apt/tests/data/test_debs/gdebi-test12.deb
# /python-apt/tests/data/test_debs/gdebi-test5.deb
# /python-apt/tests/data/test_debs/gdebi-test8.deb
# /python-apt/tests/data/test_debs/gdebi-test7.deb
# /python-apt/tests/data/test_debs/gdebi-test10.deb
# /python-apt/tests/data/test_debs/data-tar-xz.deb
# /python-apt/tests/data/test_debs/utf8-package_1.0-1_all.deb
# /python-apt/tests/data/test_debs/gdebi-test1.deb
# /python-apt/tests/data/test_debs/gdebi-test3.deb
# /python-apt/tests/data/test_debs/hello_2.5-1.dsc
# /python-apt/tests/data/test_debs/impossible-build-depends_2.5-1.dsc
# /python-apt/tests/data/test_debs/testdep-same-arch_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/multiarch-test1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test9.deb
# /python-apt/tests/data/test_debs/testdep-allowed-any_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/data-tar.deb
# /python-apt/tests/data/test_debs/data-tar-broken.deb
# /python-apt/tests/data/test_debs/gdebi-test4.deb
# /python-apt/tests/data/test_debs/gdebi-test13.deb
# /python-apt/tests/data/test_debs/gdebi-test2.deb
# /python-apt/tests/data/test_debs/var/lib/dpkg/status
# /python-apt/tests/data/test_debs/var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_maverick_main_binary-i386_Packages
# /python-apt/tests/data/test_debs/etc/apt/sources.list
# /python-apt/tests/data/test-source-repo/Sources
# /python-apt/tests/data/test-repo2/Packages.gz
# /python-apt/aptsources/distro.py
# /python-apt/aptsources/sourceslist.py
# /python-apt/aptsources/__init__.py
# /python-apt/aptsources/distinfo.py
# /python-apt/python_apt.egg-info/SOURCES.txt
# /python-apt/python_apt.egg-info/dependency_links.txt
# /python-apt/python_apt.egg-info/PKG-INFO
# /python-apt/python_apt.egg-info/top_level.txt
# /python-apt/utils/get_ubuntu_mirrors_from_lp.py
# /python-apt/utils/get_debian_mirrors.py
# /python-apt/utils/mirrortest
# /python-apt/utils/expand_info.py
# /python-apt/doc/Makefile
# /python-apt/doc/client-example.cc
# /python-apt/doc/source/contents.rst
# /python-apt/doc/source/conf.py
# /python-apt/doc/source/library/apt.cdrom.rst
# /python-apt/doc/source/library/aptsources.distro.rst
# /python-apt/doc/source/library/apt.progress.base.rst
# /python-apt/doc/source/library/apt.package.rst
# /python-apt/doc/source/library/aptsources.distinfo.rst
# /python-apt/doc/source/library/aptsources.sourceslist.rst
# /python-apt/doc/source/library/apt.debfile.rst
# /python-apt/doc/source/library/apt.progress.text.rst
# /python-apt/doc/source/library/apt_pkg.rst
# /python-apt/doc/source/library/apt.cache.rst
# /python-apt/doc/source/library/apt_inst.rst
# /python-apt/doc/source/library/index.rst
# /python-apt/doc/source/tutorials/apt-get.rst
# /python-apt/doc/source/tutorials/apt-cdrom.rst
# /python-apt/doc/source/tutorials/contributing.rst
# /python-apt/doc/source/tutorials/index.rst
# /python-apt/doc/source/templates/indexcontent.html
# /python-apt/doc/source/templates/layout.html
# /python-apt/doc/source/whatsnew/1.0.rst
# /python-apt/doc/source/whatsnew/1.6.rst
# /python-apt/doc/source/whatsnew/1.7.rst
# /python-apt/doc/source/whatsnew/1.8.rst
# /python-apt/doc/source/whatsnew/2.0.rst
# /python-apt/doc/source/whatsnew/0.9.4.rst
# /python-apt/doc/source/whatsnew/1.4.rst
# /python-apt/doc/source/whatsnew/2.1.rst
# /python-apt/doc/source/whatsnew/0.8.0.rst
# /python-apt/doc/source/whatsnew/0.7.100.rst
# /python-apt/doc/source/whatsnew/1.1.rst
# /python-apt/doc/source/whatsnew/index.rst
# /python-apt/doc/source/c++/api.rst
# /python-apt/doc/source/c++/embedding.rst
# /python-apt/doc/source/c++/index.rst
# /python-apt/doc/source/examples/dpkg-extract.py
# /python-apt/doc/source/examples/dpkg-contents.py
# /python-apt/doc/source/examples/missing-deps.py
# /python-apt/doc/source/examples/cache-pkgfile.py
# /python-apt/doc/source/examples/dpkg-info.py
# /python-apt/doc/source/examples/update-print-uris.py
# /python-apt/doc/source/examples/cache-packages.py
# /python-apt/doc/source/examples/apt-cdrom.py
# /python-apt/doc/examples/checkstate.py
# /python-apt/doc/examples/versiontest.py
# /python-apt/doc/examples/cdrom.py
# /python-apt/doc/examples/metaindex.py
# /python-apt/doc/examples/desc.py
# /python-apt/doc/examples/indexfile.py
# /python-apt/doc/examples/configisc.py
# /python-apt/doc/examples/build-deps-old.py
# /python-apt/doc/examples/print_uris.py
# /python-apt/doc/examples/dependant-pkgs.py
# /python-apt/doc/examples/tagfile.py
# /python-apt/doc/examples/all_deps.py
# /python-apt/doc/examples/progress.py
# /python-apt/doc/examples/acquire.py
# /python-apt/doc/examples/sources.py
# /python-apt/doc/examples/depcache.py
# /python-apt/doc/examples/build-deps.py
# /python-apt/doc/examples/records.py
# /python-apt/doc/examples/deb_inspect.py
# /python-apt/doc/examples/inst.py
# /python-apt/doc/examples/action.py
# /python-apt/doc/examples/config.py
# /python-apt/doc/examples/architecture.py
# /python-apt/doc/examples/recommends.py
# /python-apt/doc/examples/update.py
# /python-apt/data/templates/Kali.mirrors
# /python-apt/data/templates/Tanglu.info.in
# /python-apt/data/templates/Debian.mirrors
# /python-apt/data/templates/Blankon.info.in
# /python-apt/data/templates/Ubuntu.info.in
# /python-apt/data/templates/Kali.info.in
# /python-apt/data/templates/Debian.info.in
# /python-apt/data/templates/Tanglu.mirrors
# /python-apt/data/templates/Ubuntu.mirrors
# /python-apt/data/templates/README.templates
# /python-apt/data/templates/gNewSense.info.in
# /python-apt/data/templates/gNewSense.mirrors
# /python-apt/data/templates/Blankon.mirrors
# /python-apt/.git/config
# /python-apt/.git/index
# /python-apt/.git/description
# /python-apt/.git/packed-refs
# /python-apt/.git/HEAD
# /python-apt/.git/refs/heads/applied/ubuntu/jammy-devel
# /python-apt/.git/refs/remotes/origin/HEAD
# /python-apt/.git/hooks/push-to-checkout.sample
# /python-apt/.git/hooks/pre-receive.sample
# /python-apt/.git/hooks/pre-merge-commit.sample
# /python-apt/.git/hooks/applypatch-msg.sample
# /python-apt/.git/hooks/pre-rebase.sample
# /python-apt/.git/hooks/pre-commit.sample
# /python-apt/.git/hooks/fsmonitor-watchman.sample
# /python-apt/.git/hooks/pre-applypatch.sample
# /python-apt/.git/hooks/update.sample
# /python-apt/.git/hooks/pre-push.sample
# /python-apt/.git/hooks/prepare-commit-msg.sample
# /python-apt/.git/hooks/post-update.sample
# /python-apt/.git/hooks/commit-msg.sample
# /python-apt/.git/logs/HEAD
# /python-apt/.git/logs/refs/heads/applied/ubuntu/jammy-devel
# /python-apt/.git/logs/refs/remotes/origin/HEAD
# /python-apt/.git/info/exclude
# /python-apt/.git/objects/pack/pack-4799cb3cf0d83094d32b3545f56597395770c70d.pack
# /python-apt/.git/objects/pack/pack-4799cb3cf0d83094d32b3545f56597395770c70d.idx
# /python-apt/typehinting/apt_pkg.pyi
# /python-apt/typehinting/apt_inst.pyi
# /python-apt/build/temp.linux-x86_64-cpython-310/python/policy.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/tarfile.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/generic.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/lock.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/progress.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/python-apt-helpers.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/arfile.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/sourcelist.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/indexfile.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/orderlist.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/pkgrecords.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/string.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/cachegroup.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/tag.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/cdrom.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/apt_instmodule.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/hashstring.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/hashes.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/depcache.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/metaindex.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/hashstringlist.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/cache.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/pkgmanager.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/acquire-item.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/pkgsrcrecords.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/acquire.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/configuration.o
# /python-apt/build/temp.linux-x86_64-cpython-310/python/apt_pkgmodule.o
# /python-apt/build/lib.linux-x86_64-cpython-310/apt_inst.cpython-310-x86_64-linux-gnu.so
# /python-apt/build/lib.linux-x86_64-cpython-310/apt_pkg.cpython-310-x86_64-linux-gnu.so
# /python-apt/build/lib.linux-x86_64-cpython-310/aptsources/distro.py
# /python-apt/build/lib.linux-x86_64-cpython-310/aptsources/sourceslist.py
# /python-apt/build/lib.linux-x86_64-cpython-310/aptsources/__init__.py
# /python-apt/build/lib.linux-x86_64-cpython-310/aptsources/distinfo.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/cdrom.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/debfile.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/__init__.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/cache.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/package.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/py.typed
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/utils.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/auth.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/progress/__init__.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/progress/text.py
# /python-apt/build/lib.linux-x86_64-cpython-310/apt/progress/base.py
# /python-apt/build/data/templates/Kali.mirrors
# /python-apt/build/data/templates/Debian.info
# /python-apt/build/data/templates/Debian.mirrors
# /python-apt/build/data/templates/Blankon.info
# /python-apt/build/data/templates/Kali.info
# /python-apt/build/data/templates/gNewSense.info
# /python-apt/build/data/templates/Ubuntu.info
# /python-apt/build/data/templates/Tanglu.mirrors
# /python-apt/build/data/templates/Ubuntu.mirrors
# /python-apt/build/data/templates/gNewSense.mirrors
# /python-apt/build/data/templates/Blankon.mirrors
# /python-apt/build/data/templates/Tanglu.info
# /python-apt/apt/cdrom.py
# /python-apt/apt/debfile.py
# /python-apt/apt/__init__.py
# /python-apt/apt/cache.py
# /python-apt/apt/package.py
# /python-apt/apt/py.typed
# /python-apt/apt/utils.py
# /python-apt/apt/auth.py
# /python-apt/apt/progress/__init__.py
# /python-apt/apt/progress/text.py
# /python-apt/apt/progress/base.py

# %%
data = pd.read_csv('/waitlist_kidney_brazil.csv', encoding='latin-1')

# %%
#checking 15 random samples
data.sample(15)
# Out:
#           Id        date  age_at_list_registration   age_cat  \
# 11335  14978  11/16/2017                        40   18.a.60
# 27839  34180   10/6/2004                        52   18.a.60
# 33101  40011   10/7/2014                        43   18.a.60
# 14342  18980   5/28/2007                        30   18.a.60
# 27032  33255   11/7/2014                        43   18.a.60
# 18193  23436    5/3/2011                        16  Menor.18
# 4769    6330  12/17/2015                        64  Maior.60
# 12466  16471   10/9/2008                        31   18.a.60
# 20471  25981    1/8/2013                        54   18.a.60
# 37891  45343   9/30/2010                        68  Maior.60
# 15214  20081   8/21/2001                        37   18.a.60
# 15766  20684   8/13/2012                        58   18.a.60
# 15668  20577    2/6/2017                        59   18.a.60
# 32736  39599   6/25/2009                        66  Maior.60
# 1589    2142  10/10/2014                        45   18.a.60
#
#        time_on_Dialysis    race sex underline_disease  diabetes Blood_type  \
# 11335           2.00000  Branca   F            Outras         1          B
# 27839          39.00000  Branca   M      Pielonefrite         1          A
# 33101          13.00000   Negra   F            Outras         1          O
# 14342           7.00000  Branca   F            Outras         1          O
# 27032           6.00000   Negra   F               HAS         1          O
# 18193          33.00000  Branca   F            Outras         1          O
# 4769           27.00000  Branca   M          Diabetes         0          O
# 12466          11.00000  Branca   F          Diabetes         0          A
# 20471           1.00000  Branca   M            Outras         1          O
# 37891          39.00000  Branca   M            Outras         1          A
# 15214           1.00000  Branca   F          Diabetes         0          O
# 15766          20.00000   Parda   M               GNC         1          O
# 15668           6.00000  Branca   M               HAS         1          A
# 32736           4.00000  Branca   F               HAS         1          A
# 1589           91.00000  Branca   F               GNC         1          A
#
#        number_transfusion gestation  number_gestation prior_transplant  \
# 11335                   1       Sim           1.00000              Não
# 27839                   0       Não               NaN              Não
# 33101                   1       Sim           2.00000              Não
# 14342                   0       Sim           2.00000              Não
# 27032                   1       Sim           3.00000              Não
# 18193                   1       Não           0.00000              Não
# 4769                    1       Não               NaN              Não
# 12466                   0       Não           0.00000              Não
# 20471                   1       Não               NaN              Não
# 37891                   0       Não               NaN              Não
# 15214                   0       Sim           1.00000              Não
# 15766                   0       Não               NaN              Não
# 15668                   0       Não               NaN              Não
# 32736                   1       Sim           6.00000              Não
# 1589                    1       Sim           3.00000              Não
#
#        number_prior_transplant subregion  cPRA     cPRA_cat  HLA_A1  HLA_A2  \
# 11335                        0   UNIFESP     0         Zero      23      29
# 27839                        0   UNICAMP     0         Zero      11      24
# 33101                        0   UNIFESP     0         Zero       2      26
# 14342                        0   UNIFESP     9   Entre_0_50      29       0
# 27032                        0   FUNDERP     3   Entre_0_50      29      32
# 18193                        0   HCFMUSP     0         Zero       1       1
# 4769                         0   HCFMUSP     0         Zero       2       3
# 12466                        0   HCFMUSP    54  Entre_50_80       1      24
# 20471                        0   UNICAMP     0         Zero      24      30
# 37891                        0   UNIFESP     0         Zero       1      26
# 15214                        0   UNIFESP     0         Zero      30       0
# 15766                        0   UNIFESP     0         Zero       3      29
# 15668                        0   UNIFESP     0         Zero       2      36
# 32736                        0   HCFMUSP    26   Entre_0_50       2      29
# 1589                         0   UNIFESP    18   Entre_0_50       2      32
#
#        HLA_B1  HLA_B2  HLA_DR1  HLA_DR2         DR_00          B_00  \
# 11335      35      50       13        0    homozigoto  heterozigoto
# 27839      44      51        7       15  heterozigoto  heterozigoto
# 33101       7      56       11       15  heterozigoto  heterozigoto
# 14342      44       0        7       13  heterozigoto    homozigoto
# 27032      15      57       11        0    homozigoto  heterozigoto
# 18193      49       8        4        3  heterozigoto  heterozigoto
# 4769       14      44        1        4  heterozigoto  heterozigoto
# 12466      52      58        4       16  heterozigoto  heterozigoto
# 20471       8      40        1       13  heterozigoto  heterozigoto
# 37891      15      57        4       13  heterozigoto  heterozigoto
# 15214      44      58        3       13  heterozigoto  heterozigoto
# 15766      35      38       13       15  heterozigoto  heterozigoto
# 15668      42      53        3       11  heterozigoto  heterozigoto
# 32736      14      58        1       15  heterozigoto  heterozigoto
# 1589       18      51       11        0    homozigoto  heterozigoto
#
#                A_00  calculated_frequency_DR.f1  calculated_frequency_DR.f2  \
# 11335  heterozigoto                     0.25000                     0.00000
# 27839  heterozigoto                     0.22000                     0.21000
# 33101  heterozigoto                     0.23000                     0.21000
# 14342    homozigoto                     0.22000                     0.25000
# 27032  heterozigoto                     0.23000                     0.00000
# 18193  heterozigoto                     0.23000                     0.18000
# 4769   heterozigoto                     0.19000                     0.23000
# 12466  heterozigoto                     0.23000                     0.07000
# 20471  heterozigoto                     0.19000                     0.25000
# 37891  heterozigoto                     0.23000                     0.25000
# 15214    homozigoto                     0.18000                     0.25000
# 15766  heterozigoto                     0.25000                     0.21000
# 15668  heterozigoto                     0.18000                     0.23000
# 32736  heterozigoto                     0.19000                     0.21000
# 1589   heterozigoto                     0.23000                     0.00000
#
#        calculated_frequency_DR.f  calculated_frequency_B.f1  \
# 11335                    0.00000                    0.21000
# 27839                    4.62000                    0.20000
# 33101                    4.83000                    0.14000
# 14342                    5.50000                    0.20000
# 27032                    0.00000                    0.19000
# 18193                    4.14000                    0.05000
# 4769                     4.37000                    0.10000
# 12466                    1.61000                    0.04000
# 20471                    4.75000                    0.08000
# 37891                    5.75000                    0.19000
# 15214                    4.50000                    0.20000
# 15766                    5.25000                    0.21000
# 15668                    4.14000                    0.04000
# 32736                    3.99000                    0.10000
# 1589                     0.00000                    0.09000
#
#        calculated_frequency_B.f2  calculated_frequency_B.f  \
# 11335                    0.04000                   0.84000
# 27839                    0.14000                   2.80000
# 33101                    0.01000                   0.14000
# 14342                    0.00000                   0.00000
# 27032                    0.06000                   1.14000
# 18193                    0.08000                   0.40000
# 4769                     0.20000                   2.00000
# 12466                    0.07000                   0.28000
# 20471                    0.09000                   0.72000
# 37891                    0.06000                   1.14000
# 15214                    0.07000                   1.40000
# 15766                    0.03000                   0.63000
# 15668                    0.06000                   0.24000
# 32736                    0.07000                   0.70000
# 1589                     0.14000                   1.26000
#
#        calculated_frequency_A.f1  calculated_frequency_A.f2  \
# 11335                    0.11000                    0.08000
# 27839                    0.10000                    0.16000
# 33101                    0.42000                    0.06000
# 14342                    0.08000                    0.00000
# 27032                    0.08000                    0.06000
# 18193                    0.17000                    0.17000
# 4769                     0.42000                    0.18000
# 12466                    0.17000                    0.16000
# 20471                    0.16000                    0.13000
# 37891                    0.17000                    0.06000
# 15214                    0.13000                    0.00000
# 15766                    0.18000                    0.08000
# 15668                    0.42000                    0.02000
# 32736                    0.42000                    0.08000
# 1589                     0.42000                    0.06000
#
#        calculated_frequency_A.f chagas anti.HBc anti.HCV agHBs  \
# 11335                   0.88000    Não      Não      Não   Não
# 27839                   1.60000    Não      Não      Não   Não
# 33101                   2.52000    Não      Não      Não   Não
# 14342                   0.00000    Não      Não      Não   Não
# 27032                   0.48000    Não      Não      Não   Não
# 18193                   2.89000    Não      Não      Não   Não
# 4769                    7.56000    Não      Não      Não   Não
# 12466                   2.72000    Não      Não      Não   Não
# 20471                   2.08000    Não      Não      Não   Não
# 37891                   1.02000    Não      Não      Não   Não
# 15214                   0.00000    Não      Não      Não   Não
# 15766                   1.44000    Não      Não      Não   Não
# 15668                   0.84000    Não      Não      Não   Não
# 32736                   3.36000    Não      Não      Não   Não
# 1589                    2.52000    Não      Não      Não   Não
#
#       patient_still_on_list  date_acutal death  Time_death   Transplant  \
# 11335                   Sim        43307   Não           8          Não
# 27839                   Não        43307   Sim          57  Óbito Lista
# 33101                   Não        43307   Não          46          Sim
# 14342                   Não        43307   Não         136          Sim
# 27032                   Sim        43307   Não          45          Não
# 18193                   Não        43307   Não          88          Sim
# 4769                    Não        43307   Não          32          Sim
# 12466                   Não        43307   Não         119          Não
# 20471                   Não        43307   Não          68          Não
# 37891                   Não        43307   Sim           1  Óbito Lista
# 15214                   Não        43307   Sim         190          Sim
# 15766                   Não        43307   Não          72          Não
# 15668                   Não        43307   Sim          17          Sim
# 32736                   Não        43307   Sim          26  Óbito Lista
# 1589                    Não        43307   Não          46          Não
#
#       Transplant_Y_N  X36MthsTx   Time_Tx priorization removed_list  \
# 11335            Não          0   8.40000          Não          Não
# 27839            Não          0  57.07000          Não          Não
# 33101            Sim          1  15.23000          Não          Não
# 14342            Sim          0  66.03000          Não          Não
# 27032            Não          0  45.23000          Não          Não
# 18193            Sim          1  10.07000          Não          Não
# 4769             Sim          1  11.03000          Não          Não
# 12466            Não          0 104.43000          Não          Sim
# 20471            Não          0  58.17000          Não          Sim
# 37891            Não          0   0.83000          Não          Não
# 15214            Sim          0 141.17000          Não          Não
# 15766            Não          0  37.80000          Não          Sim
# 15668            Sim          1  10.80000          Não          Não
# 32736            Não          0  25.60000          Não          Não
# 1589             Não          0  14.17000          Não          Sim
#
#                         razon_removed  time  event  tissue_match  \
# 11335                             NaN   252      0       0.95000
# 27839                             NaN  1712      2       0.32000
# 33101                             NaN   457      1       0.92000
# 14342                             NaN  1981      1       0.26000
# 27032                             NaN  1357      0       0.01000
# 18193                             NaN   302      1       0.32000
# 4769                              NaN   331      1       0.38000
# 12466  Removido (suspenso > 365 dias)  3133      3       0.16000
# 20471  Removido (suspenso > 365 dias)  1745      3       0.65000
# 37891                             NaN    25      2       0.80000
# 15214                             NaN  4235      1       0.23000
# 15766   Transferido para outro Estado  1134      3       0.86000
# 15668                             NaN   324      1       0.55000
# 32736                             NaN   768      2       0.70000
# 1589   Removido (suspenso > 365 dias)   425      3       0.98000
#
#        urgency_factor
# 11335         0.09000
# 27839         0.77000
# 33101         0.71000
# 14342         0.22000
# 27032         0.07000
# 18193         0.11000
# 4769          0.05000
# 12466         0.66000
# 20471         0.47000
# 37891         0.95000
# 15214         0.42000
# 15766         0.12000
# 15668         0.32000
# 32736         0.30000
# 1589          0.87000

# %% [markdown]
# Portuguese language is used, as expected, as the data is from Brazil.
# We will replace portuguese words with english when needed. Doing it right now will be computationally expensive.
# anti.HBc, anti.HCV etc are a few feature names that might be problematic because of the dot. We would be prefer to replace . with _.
# the dataset looks consistent. But we will check it feature by feature as they too many of them. We will also take actions if needed, on the spot.

# %% [markdown]
# REPLACING FEW PORTUGESE WORDS BY THE EQUIVALENT ENGLISH WORDS

# %%
data.replace(to_replace= 'Não' , value= 'NO', inplace=True)
data.replace(to_replace= 'Sim' , value= 'YES', inplace=True)
data.replace(to_replace= 'Maior.60' , value= 'Major', inplace=True)
data.replace(to_replace= '18.a.60' , value= 'Midage', inplace=True)
data.replace(to_replace= 'Menor.18' , value= 'Minor', inplace=True)
data.replace(to_replace= 'Outras' , value= 'Other', inplace=True)

# %%
data.sample(15)
# Out:
#           Id        date  age_at_list_registration age_cat  time_on_Dialysis  \
# 45087  53462  10/10/2015                        28  Midage          56.00000
# 5472    7228   7/30/2010                        55  Midage          39.00000
# 22074  27740   2/12/2016                        51  Midage           5.00000
# 9963   13155  10/25/2012                        65   Major          18.00000
# 20172  25652    6/8/2005                        60   Major          11.00000
# 46828  55433   7/11/2017                        36  Midage               NaN
# 4888    6479    4/5/2011                        66   Major           4.00000
# 46699  55287   6/22/2011                        20  Midage           2.00000
# 22427  28126   12/3/2012                        51  Midage           3.00000
# 21073  26626    3/9/2012                        66   Major           5.00000
# 11173  14760   9/22/2009                        55  Midage               NaN
# 1016    1362   3/22/2016                        53  Midage          50.00000
# 24686  30587   5/15/2007                        66   Major           7.00000
# 5173    6841   2/13/2012                        70   Major           4.00000
# 24397  30271  11/27/2007                        43  Midage          79.00000
#
#           race sex underline_disease  diabetes Blood_type  number_transfusion  \
# 45087    Parda   M               HAS         1          O                   0
# 5472     Parda   M          Diabetes         0          A                   1
# 22074    Negra   M          Diabetes         0          O                   0
# 9963    Branca   M               HAS         1          A                   0
# 20172   Branca   M          Diabetes         0          O                   0
# 46828   Branca   M          Diabetes         0          A                   0
# 4888    Branca   M               HAS         1          A                   1
# 46699   Branca   M               GNC         1          O                   0
# 22427   Branca   M               HAS         1          B                   0
# 21073    Parda   M             Other         1          O                   0
# 11173  Amarela   F             Other         1         AB                   1
# 1016     Parda   M             Other         1          A                   1
# 24686   Branca   M             Other         1          A                   0
# 5173    Branca   F             Other         1          B                   0
# 24397   Branca   M               HAS         1          O                   0
#
#       gestation  number_gestation prior_transplant  number_prior_transplant  \
# 45087        NO               NaN              YES                        1
# 5472         NO               NaN               NO                        0
# 22074        NO               NaN               NO                        0
# 9963         NO               NaN               NO                        0
# 20172        NO               NaN               NO                        0
# 46828        NO               NaN              YES                        2
# 4888         NO               NaN               NO                        0
# 46699        NO               NaN               NO                        0
# 22427        NO               NaN               NO                        0
# 21073        NO               NaN               NO                        0
# 11173       YES           2.00000               NO                        0
# 1016         NO               NaN              YES                        1
# 24686        NO               NaN               NO                        0
# 5173         NO           0.00000               NO                        0
# 24397        NO               NaN              YES                        1
#
#       subregion  cPRA    cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  \
# 45087   HCFMUSP     0        Zero       2       3      15      39        3
# 5472    UNIFESP     8  Entre_0_50      30      31      15      35        3
# 22074   HCFMUSP     0        Zero      29      30      18      45        9
# 9963    HCFMUSP     0        Zero       2       2      51      50        7
# 20172   FUNDERP     0        Zero       2      24       0      51        0
# 46828   HCFMUSP     0        Zero      30       2      39      13        8
# 4888    UNIFESP     1  Entre_0_50       3      24      35      57        1
# 46699   UNIFESP     0        Zero       1      68      53      57        7
# 22427   UNIFESP     0        Zero       2      24      18      35        4
# 21073   HCFMUSP     0        Zero       2      68      39      42       11
# 11173   UNIFESP    26  Entre_0_50      24      26      40      54        4
# 1016    UNIFESP     0        Zero      23      30      15      18        7
# 24686   UNIFESP     0        Zero       1      24       8      14        1
# 5173    UNIFESP     1  Entre_0_50       2       3       7      41       10
# 24397   UNIFESP     0        Zero       1      24      15      49        4
#
#        HLA_DR2         DR_00          B_00          A_00  \
# 45087        4  heterozigoto  heterozigoto  heterozigoto
# 5472         8  heterozigoto  heterozigoto  heterozigoto
# 22074       11  heterozigoto  heterozigoto  heterozigoto
# 9963         4  heterozigoto  heterozigoto  heterozigoto
# 20172       14    homozigoto    homozigoto  heterozigoto
# 46828        7  heterozigoto  heterozigoto  heterozigoto
# 4888        11  heterozigoto  heterozigoto  heterozigoto
# 46699       13  heterozigoto  heterozigoto  heterozigoto
# 22427       14  heterozigoto  heterozigoto  heterozigoto
# 21073       16  heterozigoto  heterozigoto  heterozigoto
# 11173        8  heterozigoto  heterozigoto  heterozigoto
# 1016        13  heterozigoto  heterozigoto  heterozigoto
# 24686        3  heterozigoto  heterozigoto  heterozigoto
# 5173        15  heterozigoto  heterozigoto  heterozigoto
# 24397       13  heterozigoto  heterozigoto  heterozigoto
#
#        calculated_frequency_DR.f1  calculated_frequency_DR.f2  \
# 45087                     0.18000                     0.23000
# 5472                      0.18000                     0.12000
# 22074                     0.04000                     0.23000
# 9963                      0.22000                     0.23000
# 20172                     0.00000                     0.07000
# 46828                     0.12000                     0.22000
# 4888                      0.19000                     0.23000
# 46699                     0.22000                     0.25000
# 22427                     0.23000                     0.07000
# 21073                     0.23000                     0.07000
# 11173                     0.23000                     0.12000
# 1016                      0.22000                     0.25000
# 24686                     0.19000                     0.18000
# 5173                      0.05000                     0.21000
# 24397                     0.23000                     0.25000
#
#        calculated_frequency_DR.f  calculated_frequency_B.f1  \
# 45087                    4.14000                    0.19000
# 5472                     2.16000                    0.19000
# 22074                    0.92000                    0.09000
# 9963                     5.06000                    0.14000
# 20172                    0.00000                    0.00000
# 46828                    2.64000                    0.06000
# 4888                     4.37000                    0.21000
# 46699                    5.50000                    0.06000
# 22427                    1.61000                    0.09000
# 21073                    1.61000                    0.06000
# 11173                    2.76000                    0.09000
# 1016                     5.50000                    0.19000
# 24686                    3.42000                    0.08000
# 5173                     1.05000                    0.14000
# 24397                    5.75000                    0.19000
#
#        calculated_frequency_B.f2  calculated_frequency_B.f  \
# 45087                    0.06000                   1.14000
# 5472                     0.21000                   3.99000
# 22074                    0.05000                   0.45000
# 9963                     0.04000                   0.56000
# 20172                    0.14000                   0.00000
# 46828                    0.04000                   0.24000
# 4888                     0.06000                   1.26000
# 46699                    0.06000                   0.36000
# 22427                    0.21000                   1.89000
# 21073                    0.04000                   0.24000
# 11173                    0.00000                   0.00000
# 1016                     0.09000                   1.71000
# 24686                    0.10000                   0.80000
# 5173                     0.02000                   0.28000
# 24397                    0.05000                   0.95000
#
#        calculated_frequency_A.f1  calculated_frequency_A.f2  \
# 45087                    0.42000                    0.18000
# 5472                     0.13000                    0.08000
# 22074                    0.08000                    0.13000
# 9963                     0.42000                    0.42000
# 20172                    0.42000                    0.16000
# 46828                    0.13000                    0.42000
# 4888                     0.18000                    0.16000
# 46699                    0.17000                    0.13000
# 22427                    0.42000                    0.16000
# 21073                    0.42000                    0.13000
# 11173                    0.16000                    0.06000
# 1016                     0.11000                    0.13000
# 24686                    0.17000                    0.16000
# 5173                     0.42000                    0.18000
# 24397                    0.17000                    0.16000
#
#        calculated_frequency_A.f chagas anti.HBc anti.HCV agHBs  \
# 45087                   7.56000     NO       NO       NO    NO
# 5472                    1.04000     NO       NO       NO    NO
# 22074                   1.04000     NO       NO       NO    NO
# 9963                   17.64000     NO       NO       NO    NO
# 20172                   6.72000     NO       NO       NO    NO
# 46828                   5.46000     NO       NO       NO    NO
# 4888                    2.88000     NO       NO       NO    NO
# 46699                   2.21000     NO       NO       NO    NO
# 22427                   6.72000     NO       NO       NO    NO
# 21073                   5.46000     NO       NO       NO    NO
# 11173                   0.96000     NO       NO       NO    NO
# 1016                    1.43000     NO       NO       NO    NO
# 24686                   2.72000     NO       NO       NO    NO
# 5173                    7.56000     NO       NO       NO    NO
# 24397                   2.72000     NO       NO       NO    NO
#
#       patient_still_on_list  date_acutal death  Time_death   Transplant  \
# 45087                   YES        43307    NO          34           NO
# 5472                     NO        43307   YES          48  Óbito Lista
# 22074                    NO        43307    NO          30           NO
# 9963                     NO        43307    NO          70          YES
# 20172                    NO        43307   YES         116  Óbito Lista
# 46828                    NO        43307    NO          13           NO
# 4888                     NO        43307   YES           4  Óbito Lista
# 46699                    NO        43307    NO          86          YES
# 22427                    NO        43307    NO          69          YES
# 21073                    NO        43307   YES          14  Óbito Lista
# 11173                    NO        43307   YES          17  Óbito Lista
# 1016                     NO        43307   YES          23  Óbito Lista
# 24686                    NO        43307    NO         136           NO
# 5173                     NO        43307   YES          55  Óbito Lista
# 24397                    NO        43307    NO         130          YES
#
#       Transplant_Y_N  X36MthsTx   Time_Tx priorization removed_list  \
# 45087             NO          0  34.00000           NO           NO
# 5472              NO          0  48.17000           NO           NO
# 22074             NO          0  12.17000           NO          YES
# 9963             YES          0  37.70000           NO           NO
# 20172             NO          0 115.90000           NO           NO
# 46828             NO          0  10.47000           NO          YES
# 4888              NO          0   3.97000           NO           NO
# 46699            YES          1  27.57000           NO           NO
# 22427            YES          1  16.33000           NO           NO
# 21073             NO          0  14.13000           NO           NO
# 11173             NO          0  13.73000           NO          YES
# 1016              NO          0  23.23000           NO           NO
# 24686             NO          0  20.63000           NO          YES
# 5173              NO          0  55.13000           NO           NO
# 24397            YES          0  47.50000           NO           NO
#
#                         razon_removed  time  event  tissue_match  \
# 45087                             NaN  1020      0       0.92000
# 5472                              NaN  1445      2       0.81000
# 22074  Removido (suspenso > 365 dias)   365      3       0.66000
# 9963                              NaN  1131      1       0.91000
# 20172                             NaN  3477      2       0.69000
# 46828            Removido pela equipe   314      3       0.82000
# 4888                              NaN   119      2       0.21000
# 46699                             NaN   827      1       0.05000
# 22427                             NaN   490      1       0.90000
# 21073                             NaN   424      2       0.68000
# 11173         Removido administrativo   516      2       0.61000
# 1016                              NaN   697      2       0.94000
# 24686  Removido (suspenso > 365 dias)   619      3       0.02000
# 5173                              NaN  1654      2       0.14000
# 24397                             NaN  1425      1       0.45000
#
#        urgency_factor
# 45087         0.55000
# 5472          0.71000
# 22074         0.83000
# 9963          0.63000
# 20172         0.48000
# 46828         0.04000
# 4888          0.02000
# 46699         0.71000
# 22427         0.86000
# 21073         0.07000
# 11173         0.34000
# 1016          0.28000
# 24686         0.50000
# 5173          0.93000
# 24397         0.46000

# %% [markdown]
# RENAMING UNCLEAR ATTRIBUTES

# %%
data.rename(columns = {'anti.HBc':'HBC_antibody', 'anti.HCV':'HCV_antibody'}, inplace=True)
data.rename(columns = {'number_prior_transplant':'no_prior_trans'}, inplace=True)

# %%
data.sample(3)
# Out:
#           Id        date  age_at_list_registration age_cat  time_on_Dialysis  \
# 46470  55030  11/12/2014                        58  Midage           7.00000
# 48125  56905    6/3/2005                        64   Major          10.00000
# 41265  49177   6/15/2013                        65   Major           2.00000
#
#          race sex underline_disease  diabetes Blood_type  number_transfusion  \
# 46470   Negra   F               HAS         1          A                   0
# 48125  Branca   F             Other         1          B                   0
# 41265  Branca   M          Diabetes         0         AB                   0
#
#       gestation  number_gestation prior_transplant  no_prior_trans subregion  \
# 46470       YES           1.00000               NO               0   HCFMUSP
# 48125       YES           2.00000               NO               0   FUNDERP
# 41265        NO               NaN               NO               0   HCFMUSP
#
#        cPRA cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 46470     0     Zero      23      29      45      51        3       14
# 48125     0     Zero       0       2      18      35       11       14
# 41265     0     Zero       1       2       8      35        4       11
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 46470  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 48125  heterozigoto  heterozigoto    homozigoto                     0.23000
# 41265  heterozigoto  heterozigoto  heterozigoto                     0.23000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 46470                     0.07000                    1.26000
# 48125                     0.07000                    1.61000
# 41265                     0.23000                    5.29000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 46470                    0.05000                    0.14000
# 48125                    0.09000                    0.21000
# 41265                    0.08000                    0.21000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 46470                   0.70000                    0.11000
# 48125                   1.89000                    0.00000
# 41265                   1.68000                    0.17000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 46470                    0.08000                   0.88000     NO
# 48125                    0.42000                   0.00000    NaN
# 41265                    0.42000                   7.14000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 46470           NO           NO    NO                   YES        43307
# 48125           NO          NaN   NaN                    NO        43307
# 41265           NO           NO    NO                    NO        43307
#
#       death  Time_death Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 46470    NO          45         NO             NO          0 45.07000
# 48125    NO         160        YES            YES          1  4.87000
# 41265   YES          29        YES            YES          1 27.50000
#
#       priorization removed_list razon_removed  time  event  tissue_match  \
# 46470           NO           NO           NaN  1352      0       0.35000
# 48125           NO           NO           NaN   146      1       0.10000
# 41265           NO           NO           NaN   825      1       0.18000
#
#        urgency_factor
# 46470         0.79000
# 48125         0.53000
# 41265         0.30000

# %%
data.rename(columns = {'age_at_list_registration':'age_rec'}, inplace=True)

# %%
data.sample(6)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis    race sex  \
# 3544    4773  5/25/2007       58  Midage           3.00000  Branca   F
# 36797  44132  8/11/2006       66   Major               NaN  Branca   F
# 47105  55765  1/29/2014       55  Midage          10.00000   Negra   M
# 7661   10110  2/28/2008       72   Major           2.00000   Negra   F
# 44332  52607  8/24/2010       45  Midage         123.00000  Branca   F
# 19584  24986   1/4/2013       37  Midage           9.00000  Branca   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 3544                HAS         1          B                   0       YES
# 36797             Other         1         AB                   0       YES
# 47105               HAS         1          O                   0        NO
# 7661                HAS         1          O                   0       YES
# 44332               GNC         1          O                   1       YES
# 19584               GNC         1          A                   1        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 3544            6.00000               NO               0   HCFMUSP     0
# 36797           4.00000               NO               0   FUNDERP     0
# 47105               NaN               NO               0   UNIFESP     0
# 7661            7.00000               NO               0   HCFMUSP    44
# 44332           3.00000              YES               1   FUNDERP     0
# 19584           0.00000               NO               0   UNIFESP    99
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 3544         Zero       1       2      44      49        4       13
# 36797        Zero       1      31      50      52       13       15
# 47105        Zero       2      66       7      45        4       15
# 7661   Entre_0_50       1      74      18      44        3       15
# 44332        Zero      11      24      27      44        1        0
# 19584    Maior_80      24       0      18      35       14        0
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 3544   heterozigoto  heterozigoto  heterozigoto                     0.23000
# 36797  heterozigoto  heterozigoto  heterozigoto                     0.25000
# 47105  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 7661   heterozigoto  heterozigoto  heterozigoto                     0.18000
# 44332    homozigoto  heterozigoto  heterozigoto                     0.19000
# 19584    homozigoto  heterozigoto    homozigoto                     0.07000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 3544                      0.25000                    5.75000
# 36797                     0.21000                    5.25000
# 47105                     0.21000                    4.83000
# 7661                      0.21000                    3.78000
# 44332                     0.00000                    0.00000
# 19584                     0.00000                    0.00000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 3544                     0.20000                    0.05000
# 36797                    0.04000                    0.04000
# 47105                    0.14000                    0.05000
# 7661                     0.09000                    0.20000
# 44332                    0.04000                    0.20000
# 19584                    0.09000                    0.21000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 3544                    1.00000                    0.17000
# 36797                   0.16000                    0.17000
# 47105                   0.70000                    0.42000
# 7661                    1.80000                    0.17000
# 44332                   0.80000                    0.10000
# 19584                   1.89000                    0.16000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 3544                     0.42000                   7.14000     NO
# 36797                    0.08000                   1.36000     NO
# 47105                    0.02000                   0.84000     NO
# 7661                     0.04000                   0.68000     NO
# 44332                    0.16000                   1.60000     NO
# 19584                    0.00000                   0.00000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 3544            NO           NO    NO                    NO        43307
# 36797           NO           NO    NO                    NO        43307
# 47105           NO           NO    NO                   YES        43307
# 7661            NO           NO    NO                    NO        43307
# 44332           NO           NO    NO                    NO        43307
# 19584           NO           NO    NO                   YES        43307
#
#       death  Time_death   Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 3544    YES          33  Óbito Lista             NO          0 32.53000
# 36797    NO         146           NO             NO          0 33.77000
# 47105    NO          55           NO             NO          0 54.63000
# 7661    YES          20  Óbito Lista             NO          0 19.53000
# 44332    NO          96          YES            YES          0 53.13000
# 19584    NO          68           NO             NO          0 67.63000
#
#       priorization removed_list                   razon_removed  time  event  \
# 3544            NO           NO                             NaN   976      2
# 36797           NO          YES  Removido (suspenso > 365 dias)  1013      3
# 47105           NO           NO                             NaN  1639      0
# 7661            NO           NO                             NaN   586      2
# 44332           NO           NO                             NaN  1594      1
# 19584           NO           NO                             NaN  2029      0
#
#        tissue_match  urgency_factor
# 3544        0.64000         0.11000
# 36797       0.84000         0.11000
# 47105       0.55000         0.22000
# 7661        0.35000         0.22000
# 44332       0.82000         0.55000
# 19584       0.95000         0.51000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48153 entries, 0 to 48152
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          48153 non-null  int64
#  1   date                        48153 non-null  object
#  2   age_rec                     48153 non-null  int64
#  3   age_cat                     48153 non-null  object
#  4   time_on_Dialysis            46817 non-null  float64
#  5   race                        48153 non-null  object
#  6   sex                         48153 non-null  object
#  7   underline_disease           48153 non-null  object
#  8   diabetes                    48153 non-null  int64
#  9   Blood_type                  48153 non-null  object
#  10  number_transfusion          48153 non-null  int64
#  11  gestation                   48153 non-null  object
#  12  number_gestation            19464 non-null  float64
#  13  prior_transplant            48153 non-null  object
#  14  no_prior_trans              48153 non-null  int64
#  15  subregion                   48153 non-null  object
#  16  cPRA                        48153 non-null  int64
#  17  cPRA_cat                    48153 non-null  object
#  18  HLA_A1                      48153 non-null  int64
#  19  HLA_A2                      48153 non-null  int64
#  20  HLA_B1                      48153 non-null  int64
#  21  HLA_B2                      48153 non-null  int64
#  22  HLA_DR1                     48153 non-null  int64
#  23  HLA_DR2                     48153 non-null  int64
#  24  DR_00                       48153 non-null  object
#  25  B_00                        48153 non-null  object
#  26  A_00                        48153 non-null  object
#  27  calculated_frequency_DR.f1  48153 non-null  float64
#  28  calculated_frequency_DR.f2  48153 non-null  float64
#  29  calculated_frequency_DR.f   48153 non-null  float64
#  30  calculated_frequency_B.f1   48153 non-null  float64
#  31  calculated_frequency_B.f2   48153 non-null  float64
#  32  calculated_frequency_B.f    48153 non-null  float64
#  33  calculated_frequency_A.f1   48153 non-null  float64
#  34  calculated_frequency_A.f2   48153 non-null  float64
#  35  calculated_frequency_A.f    48153 non-null  float64
#  36  chagas                      44141 non-null  object
#  37  HBC_antibody                48153 non-null  object
#  38  HCV_antibody                44141 non-null  object
#  39  agHBs                       44141 non-null  object
#  40  patient_still_on_list       48153 non-null  object
#  41  date_acutal                 48153 non-null  int64
#  42  death                       48153 non-null  object
#  43  Time_death                  48153 non-null  int64
#  44  Transplant                  48153 non-null  object
#  45  Transplant_Y_N              48153 non-null  object
#  46  X36MthsTx                   48153 non-null  int64
#  47  Time_Tx                     48153 non-null  float64
#  48  priorization                48153 non-null  object
#  49  removed_list                48153 non-null  object
#  50  razon_removed               15295 non-null  object
#  51  time                        48153 non-null  int64
#  52  event                       48153 non-null  int64
#  53  tissue_match                48153 non-null  float64
#  54  urgency_factor              48153 non-null  float64
# dtypes: float64(14), int64(17), object(24)
# memory usage: 20.2+ MB

# %%
#Converting the 'date' feature from string to datetime format
data['date']= pd.to_datetime(data['date'])

# %%
data.sample(10)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis    race sex  \
# 40081  47820 2013-10-22       24  Midage          18.00000  Branca   M
# 32727  39589 2016-10-24       73   Major           6.00000  Branca   F
# 44318  52591 2009-06-25       14   Minor           5.00000  Branca   F
# 29052  35513 2006-01-23       60   Major           1.00000   Negra   M
# 37565  44984 2014-11-28       68   Major          11.00000  Branca   M
# 36262  43552 2002-10-03       47  Midage          16.00000  Branca   F
# 29586  36109 2014-01-31       43  Midage          68.00000   Parda   F
# 3043    4101 2017-12-04       39  Midage          19.00000  Branca   F
# 22716  28448 2015-11-05       61   Major           3.00000  Branca   M
# 46244  54784 2007-11-14       17   Minor          10.00000  Branca   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 40081             Other         1          O                   0        NO
# 32727          Diabetes         0         AB                   1       YES
# 44318               HAS         1          O                   0        NO
# 29052             Other         1          A                   0        NO
# 37565               HAS         1          A                   0        NO
# 36262             Other         1          O                   2        NO
# 29586               HAS         1          A                   0       YES
# 3043              Other         1          B                   1       YES
# 22716             Other         1          O                   0        NO
# 46244               GNC         1         AB                   0        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 40081               NaN               NO               0   UNIFESP     0
# 32727           3.00000               NO               0   HCFMUSP     1
# 44318           0.00000               NO               0   HCFMUSP     0
# 29052               NaN               NO               0   HCFMUSP     0
# 37565               NaN               NO               0   HCFMUSP     0
# 36262           0.00000               NO               0   FUNDERP     0
# 29586           5.00000              YES               1   FUNDERP    99
# 3043            3.00000               NO               0   UNIFESP   100
# 22716               NaN               NO               0   HCFMUSP     0
# 46244           0.00000               NO               0   HCFMUSP     0
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 40081        Zero       3      24       7      35       13       14
# 32727  Entre_0_50      23      68      40      44        7       13
# 44318        Zero       2       0      15       0        8       13
# 29052        Zero       2      68       0      58        7       16
# 37565        Zero       2      26      15      51       11       11
# 36262        Zero       2      26      18      48        9       14
# 29586    Maior_80      23      68      40      45        4       11
# 3043     Maior_80      23      30       8      13        7       13
# 22716        Zero      11      31      35       0        1        0
# 46244        Zero      34      68       8      58        1       11
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 40081  heterozigoto  heterozigoto  heterozigoto                     0.25000
# 32727  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 44318  heterozigoto    homozigoto    homozigoto                     0.12000
# 29052  heterozigoto    homozigoto  heterozigoto                     0.22000
# 37565  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 36262  heterozigoto  heterozigoto  heterozigoto                     0.04000
# 29586  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 3043   heterozigoto  heterozigoto  heterozigoto                     0.22000
# 22716    homozigoto    homozigoto  heterozigoto                     0.19000
# 46244  heterozigoto  heterozigoto  heterozigoto                     0.19000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 40081                     0.07000                    1.75000
# 32727                     0.25000                    5.50000
# 44318                     0.25000                    3.00000
# 29052                     0.07000                    1.54000
# 37565                     0.23000                    5.29000
# 36262                     0.07000                    0.28000
# 29586                     0.23000                    5.29000
# 3043                      0.25000                    5.50000
# 22716                     0.00000                    0.00000
# 46244                     0.23000                    4.37000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 40081                    0.14000                    0.21000
# 32727                    0.09000                    0.20000
# 44318                    0.19000                    0.00000
# 29052                    0.00000                    0.07000
# 37565                    0.19000                    0.14000
# 36262                    0.09000                    0.01000
# 29586                    0.09000                    0.05000
# 3043                     0.08000                    0.04000
# 22716                    0.21000                    0.00000
# 46244                    0.08000                    0.07000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 40081                   2.94000                    0.18000
# 32727                   1.80000                    0.11000
# 44318                   0.00000                    0.42000
# 29052                   0.00000                    0.42000
# 37565                   2.66000                    0.42000
# 36262                   0.09000                    0.42000
# 29586                   0.45000                    0.11000
# 3043                    0.32000                    0.11000
# 22716                   0.00000                    0.10000
# 46244                   0.56000                    0.02000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 40081                    0.16000                   2.88000     NO
# 32727                    0.13000                   1.43000     NO
# 44318                    0.00000                   0.00000     NO
# 29052                    0.13000                   5.46000     NO
# 37565                    0.06000                   2.52000     NO
# 36262                    0.06000                   2.52000     NO
# 29586                    0.13000                   1.43000     NO
# 3043                     0.13000                   1.43000     NO
# 22716                    0.08000                   0.80000    YES
# 46244                    0.13000                   0.26000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 40081           NO           NO    NO                   YES        43307
# 32727           NO           NO    NO                   YES        43307
# 44318           NO           NO    NO                    NO        43307
# 29052           NO           NO    NO                    NO        43307
# 37565           NO           NO    NO                    NO        43307
# 36262           NO           NO    NO                    NO        43307
# 29586           NO           NO    NO                   YES        43307
# 3043            NO           NO    NO                   YES        43307
# 22716           NO          YES   YES                   YES        43307
# 46244           NO           NO    NO                    NO        43307
#
#       death  Time_death   Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 40081    NO          58           NO             NO          0 57.93000
# 32727    NO          21           NO             NO          0 21.33000
# 44318    NO         111           NO             NO          0 21.10000
# 29052    NO         152           NO             NO          0 60.07000
# 37565   YES           2  Óbito Lista             NO          0  1.90000
# 36262    NO         193           NO             NO          0 55.27000
# 29586    NO          55           NO             NO          0 54.57000
# 3043     NO           8           NO             NO          0  7.80000
# 22716    NO          33           NO             NO          0 33.13000
# 46244    NO         130           NO             NO          0 18.67000
#
#       priorization removed_list                   razon_removed  time  event  \
# 40081           NO           NO                             NaN  1738      0
# 32727           NO           NO                             NaN   640      0
# 44318           NO          YES  Removido (suspenso > 365 dias)   633      3
# 29052           NO          YES  Removido (suspenso > 365 dias)  1802      3
# 37565           NO           NO                             NaN    57      2
# 36262           NO          YES  Removido (suspenso > 365 dias)  1658      3
# 29586           NO           NO                             NaN  1637      0
# 3043            NO           NO                             NaN   234      0
# 22716           NO           NO                             NaN   994      0
# 46244           NO          YES  Removido (suspenso > 365 dias)   560      3
#
#        tissue_match  urgency_factor
# 40081       0.82000         0.80000
# 32727       0.21000         0.39000
# 44318       0.26000         0.66000
# 29052       0.29000         0.24000
# 37565       0.24000         0.49000
# 36262       0.04000         0.93000
# 29586       0.31000         0.03000
# 3043        0.34000         0.94000
# 22716       0.25000         0.11000
# 46244       0.69000         0.12000

# %% [markdown]
# SURVIVAL ANALYSIS

# %% [markdown]
#      * In survival analysis methods, we first classify on the basis of E), and then we regress on the basis of T(duration)
#     * Censored subset is that subset of dataset which leaves out its effect on the outcomes midway
#     * In survival analysis, we try to take as much information as we can from the censored data

# %%
startdate = pd.to_datetime('2000-01-01')
#beginning of study
enddate = pd.to_datetime('2017-12-31')
#end of study

# %%
data.loc[data['date'] < startdate].sum()
# Out:
# <ipython-input-24-9313d5e65ca6>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[data['date'] < startdate].sum()
# Id                           0.00000
# age_rec                      0.00000
# age_cat                      0.00000
# time_on_Dialysis             0.00000
# race                         0.00000
# sex                          0.00000
# underline_disease            0.00000
# diabetes                     0.00000
# Blood_type                   0.00000
# number_transfusion           0.00000
# gestation                    0.00000
# number_gestation             0.00000
# prior_transplant             0.00000
# no_prior_trans               0.00000
# subregion                    0.00000
# cPRA                         0.00000
# cPRA_cat                     0.00000
# HLA_A1                       0.00000
# HLA_A2                       0.00000
# HLA_B1                       0.00000
# HLA_B2                       0.00000
# HLA_DR1                      0.00000
# HLA_DR2                      0.00000
# DR_00                        0.00000
# B_00                         0.00000
# A_00                         0.00000
# calculated_frequency_DR.f1   0.00000
# calculated_frequency_DR.f2   0.00000
# calculated_frequency_DR.f    0.00000
# calculated_frequency_B.f1    0.00000
# calculated_frequency_B.f2    0.00000
# calculated_frequency_B.f     0.00000
# calculated_frequency_A.f1    0.00000
# calculated_frequency_A.f2    0.00000
# calculated_frequency_A.f     0.00000
# chagas                       0.00000
# HBC_antibody                 0.00000
# HCV_antibody                 0.00000
# agHBs                        0.00000
# patient_still_on_list        0.00000
# date_acutal                  0.00000
# death                        0.00000
# Time_death                   0.00000
# Transplant                   0.00000
# Transplant_Y_N               0.00000
# X36MthsTx                    0.00000
# Time_Tx                      0.00000
# priorization                 0.00000
# removed_list                 0.00000
# razon_removed                0.00000
# time                         0.00000
# event                        0.00000
# tissue_match                 0.00000
# urgency_factor               0.00000
# dtype: float64

# %% [markdown]
# We have no patient registered before when the study began. So there is no left censored data.

# %% [markdown]
# TREATMENT OF DUPLICATE VALUES

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  * No duplicate values
#  * No treatment required

# %% [markdown]
# TREATMENT OF DUPLICATE VALUES

# %%
data.isna().sum()/len(data)*100
# Out:
# Id                            0.00000
# date                          0.00000
# age_rec                       0.00000
# age_cat                       0.00000
# time_on_Dialysis              2.77449
# race                          0.00000
# sex                           0.00000
# underline_disease             0.00000
# diabetes                      0.00000
# Blood_type                    0.00000
# number_transfusion            0.00000
# gestation                     0.00000
# number_gestation             59.57884
# prior_transplant              0.00000
# no_prior_trans                0.00000
# subregion                     0.00000
# cPRA                          0.00000
# cPRA_cat                      0.00000
# HLA_A1                        0.00000
# HLA_A2                        0.00000
# HLA_B1                        0.00000
# HLA_B2                        0.00000
# HLA_DR1                       0.00000
# HLA_DR2                       0.00000
# DR_00                         0.00000
# B_00                          0.00000
# A_00                          0.00000
# calculated_frequency_DR.f1    0.00000
# calculated_frequency_DR.f2    0.00000
# calculated_frequency_DR.f     0.00000
# calculated_frequency_B.f1     0.00000
# calculated_frequency_B.f2     0.00000
# calculated_frequency_B.f      0.00000
# calculated_frequency_A.f1     0.00000
# calculated_frequency_A.f2     0.00000
# calculated_frequency_A.f      0.00000
# chagas                        8.33178
# HBC_antibody                  0.00000
# HCV_antibody                  8.33178
# agHBs                         8.33178
# patient_still_on_list         0.00000
# date_acutal                   0.00000
# death                         0.00000
# Time_death                    0.00000
# Transplant                    0.00000
# Transplant_Y_N                0.00000
# X36MthsTx                     0.00000
# Time_Tx                       0.00000
# priorization                  0.00000
# removed_list                  0.00000
# razon_removed                68.23666
# time                          0.00000
# event                         0.00000
# tissue_match                  0.00000
# urgency_factor                0.00000
# dtype: float64

# %% [markdown]
# time_on_Dialysis, number_gestation, chagas, agHBs, HCV_antibodies, razon_removed:: these 6 features might need 'missing value imputation'

# %% [markdown]
# (i) razon_removed

# %%
data = data.drop(columns=['razon_removed'],axis=0)

# %%
data.sample(10)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis     race sex  \
# 11210  14813 2006-02-03       63   Major          17.00000   Branca   M
# 24175  30027 2009-09-10       46  Midage         147.00000    Negra   M
# 21971  27630 2016-12-20       44  Midage          15.00000   Branca   M
# 39224  46809 2011-09-19       21  Midage           3.00000   Branca   F
# 18947  24267 2004-02-06       23  Midage           5.00000    Parda   M
# 19513  24906 2000-09-20       44  Midage          38.00000   Branca   M
# 45272  53684 2009-03-05       87   Major          10.00000  Amarela   M
# 1519    2045 2014-08-28       40  Midage          69.00000   Branca   M
# 44765  53105 2002-05-27       25  Midage           2.00000   Branca   F
# 10974  14502 2014-01-06       55  Midage           9.00000   Branca   M
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 11210          Diabetes         0          O                   0        NO
# 24175             Other         1          A                   0        NO
# 21971             Other         1          O                   1        NO
# 39224               GNC         1          O                   0       YES
# 18947               GNC         1          A                   0        NO
# 19513          Diabetes         0          A                   1        NO
# 45272               HAS         1          A                   0        NO
# 1519              Other         1          O                   1        NO
# 44765          Diabetes         0          A                   0        NO
# 10974               HAS         1          A                   0        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 11210               NaN               NO               0   UNIFESP     0
# 24175               NaN              YES               1   HCFMUSP     0
# 21971               NaN               NO               0   UNICAMP     0
# 39224           1.00000               NO               0   FUNDERP     0
# 18947               NaN               NO               0   HCFMUSP     0
# 19513               NaN               NO               0   FUNDERP    10
# 45272               NaN               NO               0   UNIFESP     0
# 1519                NaN               NO               0   UNIFESP     0
# 44765           0.00000               NO               0   FUNDERP    10
# 10974               NaN              YES               1   UNIFESP    97
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 11210        Zero       3      26      37      52        3       10
# 24175        Zero      30      66      13      51        8       12
# 21971        Zero       2      11      27      44        1        4
# 39224        Zero       2       3      51      49        9       13
# 18947        Zero       1       3       7      45        7       11
# 19513  Entre_0_50       1       2       7      53        1        4
# 45272        Zero       3      11      37      44       10       13
# 1519         Zero       1       0       7      52        4       15
# 44765  Entre_0_50      24      26       7      49        4       15
# 10974    Maior_80      68       0      27      42        1       14
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 11210  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 24175  heterozigoto  heterozigoto  heterozigoto                     0.12000
# 21971  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 39224  heterozigoto  heterozigoto  heterozigoto                     0.04000
# 18947  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 19513  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 45272  heterozigoto  heterozigoto  heterozigoto                     0.05000
# 1519   heterozigoto  heterozigoto    homozigoto                     0.23000
# 44765  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 10974  heterozigoto  heterozigoto    homozigoto                     0.19000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 11210                     0.05000                    0.90000
# 24175                     0.04000                    0.48000
# 21971                     0.23000                    4.37000
# 39224                     0.25000                    1.00000
# 18947                     0.23000                    5.06000
# 19513                     0.23000                    4.37000
# 45272                     0.25000                    1.25000
# 1519                      0.21000                    4.83000
# 44765                     0.21000                    4.83000
# 10974                     0.07000                    1.33000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 11210                    0.02000                    0.04000
# 24175                    0.04000                    0.14000
# 21971                    0.04000                    0.20000
# 39224                    0.14000                    0.05000
# 18947                    0.14000                    0.05000
# 19513                    0.14000                    0.06000
# 45272                    0.02000                    0.20000
# 1519                     0.14000                    0.04000
# 44765                    0.14000                    0.05000
# 10974                    0.04000                    0.04000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 11210                   0.08000                    0.18000
# 24175                   0.56000                    0.13000
# 21971                   0.80000                    0.42000
# 39224                   0.70000                    0.42000
# 18947                   0.70000                    0.17000
# 19513                   0.84000                    0.17000
# 45272                   0.40000                    0.18000
# 1519                    0.56000                    0.17000
# 44765                   0.70000                    0.16000
# 10974                   0.16000                    0.13000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 11210                    0.06000                   1.08000     NO
# 24175                    0.02000                   0.26000     NO
# 21971                    0.10000                   4.20000     NO
# 39224                    0.18000                   7.56000     NO
# 18947                    0.18000                   3.06000     NO
# 19513                    0.42000                   7.14000    NaN
# 45272                    0.10000                   1.80000     NO
# 1519                     0.00000                   0.00000     NO
# 44765                    0.06000                   0.96000     NO
# 10974                    0.00000                   0.00000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 11210           NO           NO    NO                    NO        43307
# 24175           NO           NO    NO                    NO        43307
# 21971           NO           NO    NO                   YES        43307
# 39224           NO           NO    NO                    NO        43307
# 18947           NO           NO    NO                    NO        43307
# 19513           NO          NaN   NaN                    NO        43307
# 45272           NO           NO    NO                    NO        43307
# 1519            NO           NO    NO                    NO        43307
# 44765           NO           NO    NO                    NO        43307
# 10974           NO           NO    NO                   YES        43307
#
#       death  Time_death   Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 11210   YES          29  Óbito Lista             NO          0 29.30000
# 24175    NO         108           NO             NO          0 90.43000
# 21971    NO          19           NO             NO          0 19.43000
# 39224    NO          83          YES            YES          0 47.17000
# 18947    NO         176           NO             NO          0 12.27000
# 19513   YES           6  Óbito Lista             NO          0  5.70000
# 45272    NO         114           NO             NO          0 12.17000
# 1519     NO          48          YES            YES          1  5.97000
# 44765    NO         197           NO             NO          0 31.97000
# 10974    NO          55           NO             NO          0 55.40000
#
#       priorization removed_list  time  event  tissue_match  urgency_factor
# 11210           NO           NO   879      2       0.67000         0.62000
# 24175           NO          YES  2713      3       0.66000         0.17000
# 21971           NO           NO   583      0       0.62000         0.79000
# 39224           NO           NO  1415      1       1.00000         0.32000
# 18947           NO          YES   368      3       0.45000         0.70000
# 19513           NO           NO   171      2       0.15000         1.00000
# 45272           NO          YES   365      3       0.50000         0.87000
# 1519            NO           NO   179      1       0.61000         0.49000
# 44765           NO          YES   959      3       0.41000         0.60000
# 10974           NO           NO  1662      0       0.59000         0.26000

# %% [markdown]
# (ii) Number_gestation

# %% [markdown]
# Around 59 percent of its values are NaN.
# But we cannot drop this feature just like that or even replace the missing values with a mode
# we have to consider that the data was not entered in case of Males, and hence NaN

# %%
data[data['sex']=='M']['number_gestation'].isna().sum()
#for all val the particular val is given as NaN
# Out:
# 28679

# %%
data['number_gestation'] = np.where(data['number_gestation'].isna(), 0 , data['number_gestation'])
#sub 0 for NaN

# %%
data.sample(20)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis    race sex  \
# 41436  49359 2007-10-15       51  Midage           3.00000  Branca   M
# 47315  55990 2012-04-03       55  Midage          81.00000  Branca   M
# 43062  51161 2010-01-04       42  Midage          41.00000   Negra   M
# 32484  39329 2012-07-03       79   Major          44.00000  Branca   F
# 39259  46849 2009-06-01       22  Midage          52.00000   Negra   F
# 2806    3779 2017-04-28       46  Midage          13.00000  Branca   M
# 20807  26337 2017-04-24        1   Minor          12.00000  Branca   M
# 33357  40290 2014-07-21       66   Major           5.00000  Branca   F
# 29720  36261 2001-12-06       31  Midage           1.00000  Branca   F
# 16344  21343 2007-09-18       78   Major          58.00000  Branca   M
# 12794  16892 2013-05-17       48  Midage          43.00000   Parda   F
# 17249  22365 2016-01-04       53  Midage          11.00000   Parda   F
# 29671  36206 2013-04-02       15   Minor          17.00000   Negra   F
# 27057  33284 2012-03-05       47  Midage           7.00000   Negra   M
# 28386  34777 2008-12-17       51  Midage          24.00000  Branca   M
# 45971  54469 2011-09-19       69   Major           6.00000  Branca   M
# 2683    3614 2010-07-29       21  Midage          80.00000   Negra   F
# 4302    5737 2008-10-14       41  Midage           5.00000   Negra   M
# 27437  33709 2004-03-11       11   Minor          36.00000  Branca   F
# 28742  35173 2006-12-08       62   Major         164.00000   Parda   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 41436          Diabetes         0          A                   0        NO
# 47315             Other         1          O                   0        NO
# 43062          Diabetes         0          O                   1        NO
# 32484               HAS         1          O                   0       YES
# 39259             Other         1          A                   1        NO
# 2806                HAS         1          A                   1        NO
# 20807             Other         1          A                   3        NO
# 33357               GNC         1          O                   0       YES
# 29720             Other         1          A                   1       YES
# 16344               HAS         1          B                   0        NO
# 12794          Diabetes         0          A                   1       YES
# 17249          Diabetes         0          A                   0       YES
# 29671               HAS         1          O                   1        NO
# 27057               HAS         1          A                   0        NO
# 28386               HAS         1          O                   0        NO
# 45971             Other         1          O                   0        NO
# 2683                GNC         1          A                   1        NO
# 4302              Other         1          A                   1        NO
# 27437               GNC         1          O                   0        NO
# 28742               HAS         1          O                   0       YES
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 41436           0.00000               NO               0   FUNDERP     0
# 47315           0.00000               NO               0   UNICAMP     0
# 43062           0.00000               NO               0   UNIFESP     0
# 32484           4.00000               NO               0   UNICAMP    97
# 39259           0.00000               NO               0   UNICAMP     0
# 2806            0.00000               NO               0   HCFMUSP     0
# 20807           0.00000               NO               0   HCFMUSP     0
# 33357           3.00000               NO               0   UNICAMP    29
# 29720           1.00000               NO               0   UNIFESP     0
# 16344           0.00000              YES               1   UNIFESP    64
# 12794           1.00000               NO               0   FUNDERP     0
# 17249           7.00000               NO               0   UNIFESP    37
# 29671           0.00000               NO               0   HCFMUSP    80
# 27057           0.00000               NO               0   UNIFESP    26
# 28386           0.00000               NO               0   UNIFESP     0
# 45971           0.00000               NO               0   HCFMUSP     0
# 2683            0.00000              YES               1   UNIFESP     0
# 4302            0.00000              YES               1   UNIFESP     0
# 27437           0.00000               NO               0   UNICAMP     0
# 28742           7.00000               NO               0   FUNDERP     0
#
#           cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 41436         Zero       0       2      35      51        1       16
# 47315         Zero       1       3      44      57        7       15
# 43062         Zero      30      74      14      15        7       11
# 32484     Maior_80      30      33      14      42        1        7
# 39259         Zero       1       2       8      56        1       11
# 2806          Zero       3      26       7      57        1       13
# 20807         Zero      24      31      15      51        8       14
# 33357   Entre_0_50       2      34      35      53        7       11
# 29720         Zero      26      33       0      14        3        7
# 16344  Entre_50_80       0       3      14      15        4       13
# 12794         Zero      29      29      44      44        3        7
# 17249   Entre_0_50       1      74      57      58        7       12
# 29671  Entre_50_80      68       2      81      15       12        4
# 27057   Entre_0_50      24      24       8       8        3        3
# 28386         Zero       2       3      35      44        1       11
# 45971         Zero      24       3      41       7       15       13
# 2683          Zero       1      68      39      40        4        8
# 4302          Zero       1      33      52      53        8       13
# 27437         Zero      24      74      15      53        0       11
# 28742         Zero       2       3      42      49        8        9
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 41436  heterozigoto  heterozigoto    homozigoto                     0.19000
# 47315  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 43062  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 32484  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 39259  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 2806   heterozigoto  heterozigoto  heterozigoto                     0.19000
# 20807  heterozigoto  heterozigoto  heterozigoto                     0.12000
# 33357  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 29720  heterozigoto    homozigoto  heterozigoto                     0.18000
# 16344  heterozigoto  heterozigoto    homozigoto                     0.23000
# 12794  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 17249  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 29671  heterozigoto  heterozigoto  heterozigoto                     0.04000
# 27057  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 28386  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 45971  heterozigoto  heterozigoto  heterozigoto                     0.21000
# 2683   heterozigoto  heterozigoto  heterozigoto                     0.23000
# 4302   heterozigoto  heterozigoto  heterozigoto                     0.12000
# 27437    homozigoto  heterozigoto  heterozigoto                     0.00000
# 28742  heterozigoto  heterozigoto  heterozigoto                     0.12000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 41436                     0.07000                    1.33000
# 47315                     0.21000                    4.62000
# 43062                     0.23000                    5.06000
# 32484                     0.22000                    4.18000
# 39259                     0.23000                    4.37000
# 2806                      0.25000                    4.75000
# 20807                     0.07000                    0.84000
# 33357                     0.23000                    5.06000
# 29720                     0.22000                    3.96000
# 16344                     0.25000                    5.75000
# 12794                     0.22000                    3.96000
# 17249                     0.04000                    0.88000
# 29671                     0.23000                    0.92000
# 27057                     0.18000                    3.24000
# 28386                     0.23000                    4.37000
# 45971                     0.25000                    5.25000
# 2683                      0.12000                    2.76000
# 4302                      0.25000                    3.00000
# 27437                     0.23000                    0.00000
# 28742                     0.04000                    0.48000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 41436                    0.21000                    0.14000
# 47315                    0.20000                    0.06000
# 43062                    0.10000                    0.19000
# 32484                    0.10000                    0.04000
# 39259                    0.08000                    0.01000
# 2806                     0.14000                    0.06000
# 20807                    0.19000                    0.14000
# 33357                    0.21000                    0.06000
# 29720                    0.00000                    0.10000
# 16344                    0.10000                    0.19000
# 12794                    0.20000                    0.20000
# 17249                    0.06000                    0.07000
# 29671                    0.02000                    0.19000
# 27057                    0.08000                    0.08000
# 28386                    0.21000                    0.20000
# 45971                    0.02000                    0.14000
# 2683                     0.06000                    0.09000
# 4302                     0.04000                    0.06000
# 27437                    0.19000                    0.06000
# 28742                    0.04000                    0.05000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 41436                   2.94000                    0.00000
# 47315                   1.20000                    0.17000
# 43062                   1.90000                    0.13000
# 32484                   0.40000                    0.13000
# 39259                   0.08000                    0.17000
# 2806                    0.84000                    0.18000
# 20807                   2.66000                    0.16000
# 33357                   1.26000                    0.42000
# 29720                   0.00000                    0.06000
# 16344                   1.90000                    0.00000
# 12794                   4.00000                    0.08000
# 17249                   0.42000                    0.17000
# 29671                   0.38000                    0.13000
# 27057                   0.64000                    0.16000
# 28386                   4.20000                    0.42000
# 45971                   0.28000                    0.16000
# 2683                    0.54000                    0.17000
# 4302                    0.24000                    0.17000
# 27437                   1.14000                    0.16000
# 28742                   0.20000                    0.42000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 41436                    0.42000                   0.00000     NO
# 47315                    0.18000                   3.06000     NO
# 43062                    0.04000                   0.52000     NO
# 32484                    0.07000                   0.91000     NO
# 39259                    0.42000                   7.14000     NO
# 2806                     0.06000                   1.08000     NO
# 20807                    0.08000                   1.28000     NO
# 33357                    0.02000                   0.84000    YES
# 29720                    0.07000                   0.42000     NO
# 16344                    0.18000                   0.00000     NO
# 12794                    0.08000                   0.64000     NO
# 17249                    0.04000                   0.68000     NO
# 29671                    0.42000                   5.46000     NO
# 27057                    0.16000                   2.56000     NO
# 28386                    0.18000                   7.56000     NO
# 45971                    0.18000                   2.88000     NO
# 2683                     0.13000                   2.21000     NO
# 4302                     0.07000                   1.19000     NO
# 27437                    0.04000                   0.64000    NaN
# 28742                    0.18000                   7.56000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 41436           NO           NO    NO                    NO        43307
# 47315           NO           NO    NO                    NO        43307
# 43062           NO           NO    NO                    NO        43307
# 32484          YES           NO    NO                    NO        43307
# 39259           NO           NO    NO                    NO        43307
# 2806            NO           NO    NO                    NO        43307
# 20807           NO           NO    NO                   YES        43307
# 33357           NO           NO    NO                    NO        43307
# 29720           NO           NO    NO                    NO        43307
# 16344           NO           NO    NO                    NO        43307
# 12794           NO           NO    NO                    NO        43307
# 17249           NO           NO    NO                   YES        43307
# 29671           NO           NO    NO                    NO        43307
# 27057           NO           NO    NO                   YES        43307
# 28386           NO           NO    NO                    NO        43307
# 45971           NO           NO    NO                    NO        43307
# 2683            NO           NO    NO                    NO        43307
# 4302            NO           NO    NO                    NO        43307
# 27437           NO          NaN   NaN                    NO        43307
# 28742           NO           NO    NO                    NO        43307
#
#       death  Time_death   Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 41436   YES          19  Óbito Lista             NO          0 19.03000
# 47315   YES          25          YES            YES          1 21.73000
# 43062   YES          47  Óbito Lista             NO          0 46.97000
# 32484    NO          74           NO             NO          0 12.17000
# 39259    NO         111          YES            YES          1 33.07000
# 2806     NO          15          YES            YES          1  3.77000
# 20807    NO          15           NO             NO          0 15.27000
# 33357    NO          49           NO             NO          0 36.73000
# 29720   YES         123          YES            YES          0 66.43000
# 16344    NO         132           NO             NO          0 50.47000
# 12794    NO          63          YES            YES          1  7.03000
# 17249    NO          31           NO             NO          0 31.13000
# 29671    NO          65          YES            YES          1  6.17000
# 27057    NO          78           NO             NO          0 77.80000
# 28386    NO         117          YES            YES          0 43.37000
# 45971    NO          83           NO             NO          0 83.13000
# 2683     NO          97           NO             NO          0 41.23000
# 4302     NO         119          YES            YES          0 42.37000
# 27437   YES           7  Óbito Lista             NO          0  7.13000
# 28742    NO         142           NO             NO          0 12.87000
#
#       priorization removed_list  time  event  tissue_match  urgency_factor
# 41436           NO           NO   571      2       0.04000         0.02000
# 47315           NO           NO   652      1       0.21000         0.26000
# 43062           NO           NO  1409      2       0.95000         0.20000
# 32484           NO          YES   365      3       0.73000         0.23000
# 39259           NO           NO   992      1       0.75000         0.71000
# 2806            NO           NO   113      1       0.19000         0.98000
# 20807           NO           NO   458      0       0.51000         0.22000
# 33357           NO          YES  1102      3       0.27000         1.00000
# 29720           NO           NO  1993      1       0.03000         0.51000
# 16344           NO          YES  1514      3       0.13000         0.39000
# 12794           NO           NO   211      1       0.69000         0.66000
# 17249           NO           NO   934      0       0.41000         0.47000
# 29671           NO           NO   185      1       0.66000         0.19000
# 27057           NO           NO  2334      0       0.44000         0.04000
# 28386           NO           NO  1301      1       0.47000         0.95000
# 45971           NO          YES  2494      3       0.79000         0.37000
# 2683            NO          YES  1237      3       0.87000         0.95000
# 4302            NO           NO  1271      1       0.71000         0.74000
# 27437           NO           NO   214      2       0.58000         0.10000
# 28742           NO          YES   386      3       0.42000         0.28000

# %% [markdown]
# (iii) dialysis_duration

# %% [markdown]
# *  impute with 1 because as soon as someone's kidney fails, they are necessarily put on dialysis. And since the data is of patients awaiting cadaveric graft, everyone who is one list has had at least on session of dialysis.
# * We will even replace all zeros with 1.

# %%
data['time_on_Dialysis'] = np.where(data['time_on_Dialysis'].isna(), 1 , data['time_on_Dialysis'])
data['time_on_Dialysis'] = np.where(data['time_on_Dialysis'] == 0, 1 , data['time_on_Dialysis'])

# %% [markdown]
# (iv) HCV_antibody

# %%
sns.displot(data=data,x='HCV_antibody',color='Red')
plt.title("Bargraph of HCV_anti_bodies")
plt.show()

# %% [markdown]
# ##most of the values are 'NO'
# HCV_antibodies =
# NO, if the patient has no antibodies i.e. the patient has never been infected with HC Virus
# YES, if the patient has antibodies i.e. the patient has been or is infected with the HCV
# In general, we have to take for granted that people are not infected. So their HCV_antibodies value should be 'NO'.

# %%
data['HCV_antibody'] = np.where(data['HCV_antibody'].isna(), 'NO' , data['HCV_antibody'])#replace NaN with no

# %%
data.sample(15)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis     race sex  \
# 32701  39562 2014-06-27       51  Midage          11.00000   Branca   F
# 22329  28021 2016-07-28       62   Major          41.00000   Branca   M
# 16428  21434 2014-11-14       58  Midage          17.00000   Branca   M
# 43714  51909 2013-05-04       39  Midage          22.00000   Branca   F
# 32081  38880 2011-05-02       51  Midage          94.00000   Branca   F
# 44026  52253 2011-05-06       44  Midage         123.00000   Branca   M
# 47122  55783 2001-08-28       62   Major           1.00000   Branca   M
# 18208  23451 2013-07-24       45  Midage           4.00000   Branca   F
# 2244    3027 2007-07-10       52  Midage          13.00000   Branca   M
# 17484  22635 2015-09-17       56  Midage          22.00000  Amarela   F
# 45294  53709 2005-11-30       61   Major          18.00000    Parda   M
# 39103  46676 2004-09-13       56  Midage          20.00000   Branca   M
# 36986  44350 2010-05-24       52  Midage         131.00000    Negra   F
# 22962  28715 2001-03-09       51  Midage           4.00000   Branca   M
# 1995    2704 2015-12-11       64   Major          75.00000    Parda   M
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 32701               HAS         1          A                   1       YES
# 22329          Diabetes         0         AB                   0        NO
# 16428          Diabetes         0          O                   0        NO
# 43714             Other         1          A                   0        NO
# 32081             Other         1          O                   1       YES
# 44026               HAS         1          B                   0        NO
# 47122          Diabetes         0          A                   0        NO
# 18208               GNC         1          A                   0       YES
# 2244              Other         1          A                   0        NO
# 17484          Diabetes         0          O                   0        NO
# 45294             Other         1          O                   0        NO
# 39103               HAS         1          A                   0        NO
# 36986               HAS         1          A                   1       YES
# 22962          Diabetes         0          O                   0        NO
# 1995                HAS         1          O                   1        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 32701           4.00000               NO               0   FUNDERP    88
# 22329           0.00000               NO               0   UNIFESP     0
# 16428           0.00000               NO               0   FUNDERP     0
# 43714           0.00000               NO               0   UNICAMP     0
# 32081           5.00000               NO               0   UNIFESP    17
# 44026           0.00000              YES               1   UNIFESP     0
# 47122           0.00000               NO               0   UNIFESP     0
# 18208           3.00000               NO               0   UNIFESP     0
# 2244            0.00000               NO               0   UNICAMP     0
# 17484           0.00000               NO               0   HCFMUSP     0
# 45294           0.00000               NO               0   HCFMUSP     0
# 39103           0.00000               NO               0   FUNDERP     0
# 36986           5.00000              YES               1   UNIFESP    88
# 22962           0.00000               NO               0   HCFMUSP     4
# 1995            0.00000              YES               1   UNICAMP    20
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 32701    Maior_80       2      30      45      56        1        7
# 22329        Zero       3      66      15      52        7       15
# 16428        Zero      11      31      35      51        1        8
# 43714        Zero       2       3      15      35        7       14
# 32081  Entre_0_50       2      33       7      51        4       11
# 44026        Zero       2      32       7      14        4       12
# 47122        Zero       2      29      37      44        1        7
# 18208        Zero       2       3       7      51        7       15
# 2244         Zero       2      68      15      18        3        0
# 17484        Zero      24      26      15      52       14       15
# 45294        Zero      23      30      14      44        3        7
# 39103        Zero       2      33      14      27        0        1
# 36986    Maior_80      30      34      44      58       11       13
# 22962  Entre_0_50       2      68      35      49       14        3
# 1995   Entre_0_50       1      29      13      49        1       13
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 32701  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 22329  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 16428  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 43714  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 32081  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 44026  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 47122  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 18208  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 2244     homozigoto  heterozigoto  heterozigoto                     0.18000
# 17484  heterozigoto  heterozigoto  heterozigoto                     0.07000
# 45294  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 39103    homozigoto  heterozigoto  heterozigoto                     0.00000
# 36986  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 22962  heterozigoto  heterozigoto  heterozigoto                     0.07000
# 1995   heterozigoto  heterozigoto  heterozigoto                     0.19000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 32701                     0.22000                    4.18000
# 22329                     0.21000                    4.62000
# 16428                     0.12000                    2.28000
# 43714                     0.07000                    1.54000
# 32081                     0.23000                    5.29000
# 44026                     0.04000                    0.92000
# 47122                     0.22000                    4.18000
# 18208                     0.21000                    4.62000
# 2244                      0.00000                    0.00000
# 17484                     0.21000                    1.47000
# 45294                     0.22000                    3.96000
# 39103                     0.19000                    0.00000
# 36986                     0.25000                    5.75000
# 22962                     0.18000                    1.26000
# 1995                      0.25000                    4.75000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 32701                    0.05000                    0.01000
# 22329                    0.19000                    0.04000
# 16428                    0.21000                    0.14000
# 43714                    0.19000                    0.21000
# 32081                    0.14000                    0.14000
# 44026                    0.14000                    0.10000
# 47122                    0.02000                    0.20000
# 18208                    0.14000                    0.14000
# 2244                     0.19000                    0.09000
# 17484                    0.19000                    0.04000
# 45294                    0.10000                    0.20000
# 39103                    0.10000                    0.04000
# 36986                    0.20000                    0.07000
# 22962                    0.21000                    0.05000
# 1995                     0.04000                    0.05000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 32701                   0.05000                    0.42000
# 22329                   0.76000                    0.18000
# 16428                   2.94000                    0.10000
# 43714                   3.99000                    0.42000
# 32081                   1.96000                    0.42000
# 44026                   1.40000                    0.42000
# 47122                   0.40000                    0.42000
# 18208                   1.96000                    0.42000
# 2244                    1.71000                    0.42000
# 17484                   0.76000                    0.16000
# 45294                   2.00000                    0.11000
# 39103                   0.40000                    0.42000
# 36986                   1.40000                    0.13000
# 22962                   1.05000                    0.42000
# 1995                    0.20000                    0.17000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f chagas  \
# 32701                    0.13000                   5.46000     NO
# 22329                    0.02000                   0.36000     NO
# 16428                    0.08000                   0.80000     NO
# 43714                    0.18000                   7.56000     NO
# 32081                    0.07000                   2.94000     NO
# 44026                    0.06000                   2.52000     NO
# 47122                    0.08000                   3.36000     NO
# 18208                    0.18000                   7.56000     NO
# 2244                     0.13000                   5.46000     NO
# 17484                    0.06000                   0.96000     NO
# 45294                    0.13000                   1.43000     NO
# 39103                    0.07000                   2.94000    NaN
# 36986                    0.02000                   0.26000     NO
# 22962                    0.13000                   5.46000    NaN
# 1995                     0.08000                   1.36000     NO
#
#       HBC_antibody HCV_antibody agHBs patient_still_on_list  date_acutal  \
# 32701           NO           NO    NO                    NO        43307
# 22329           NO           NO    NO                   YES        43307
# 16428           NO           NO    NO                    NO        43307
# 43714           NO           NO    NO                    NO        43307
# 32081           NO           NO    NO                    NO        43307
# 44026          YES           NO    NO                    NO        43307
# 47122           NO           NO    NO                    NO        43307
# 18208           NO           NO    NO                    NO        43307
# 2244            NO           NO    NO                    NO        43307
# 17484           NO           NO    NO                   YES        43307
# 45294           NO           NO    NO                    NO        43307
# 39103           NO           NO   NaN                    NO        43307
# 36986           NO           NO    NO                    NO        43307
# 22962           NO           NO   NaN                    NO        43307
# 1995           YES           NO    NO                    NO        43307
#
#       death  Time_death   Transplant Transplant_Y_N  X36MthsTx  Time_Tx  \
# 32701    NO          50          YES            YES          1 25.13000
# 22329    NO          24           NO             NO          0 24.27000
# 16428    NO          45          YES            YES          1 28.30000
# 43714    NO          64          YES            YES          1 34.20000
# 32081   YES          10  Óbito Lista             NO          0  9.73000
# 44026    NO          88           NO             NO          0 32.10000
# 47122   YES          66  Óbito Lista             NO          0 66.00000
# 18208    NO          61          YES            YES          1 29.47000
# 2244    YES         100          YES            YES          0 51.70000
# 17484    NO          35           NO             NO          0 34.77000
# 45294   YES          52  Óbito Lista             NO          0 41.00000
# 39103    NO         169           NO             NO          0  9.00000
# 36986    NO         100          YES            YES          1  5.03000
# 22962   YES          34  Óbito Lista             NO          0 34.17000
# 1995    YES          11          YES            YES          1 11.27000
#
#       priorization removed_list  time  event  tissue_match  urgency_factor
# 32701           NO           NO   754      1       0.14000         0.57000
# 22329           NO           NO   728      0       0.23000         0.90000
# 16428           NO           NO   849      1       0.82000         0.81000
# 43714           NO           NO  1026      1       0.16000         0.55000
# 32081           NO           NO   292      2       0.73000         1.00000
# 44026           NO          YES   963      3       0.24000         0.84000
# 47122           NO           NO  1980      2       0.25000         0.21000
# 18208           NO           NO   884      1       0.14000         0.96000
# 2244            NO           NO  1551      1       0.27000         0.73000
# 17484           NO           NO  1043      0       0.92000         0.08000
# 45294           NO          YES  1564      2       0.73000         0.49000
# 39103           NO          YES   270      3       0.39000         0.24000
# 36986           NO           NO   151      1       0.25000         0.17000
# 22962           NO           NO  1025      2       0.97000         0.60000
# 1995            NO           NO   338      1       0.25000         0.01000

# %%
data['agHBs'].value_counts()
# Out:
# NO     44022
# YES      119
# Name: agHBs, dtype: int64

# %%
data['agHBs'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Pie Chart of HBs Antigen")
plt.show()

# %% [markdown]
# Of the non-NaN values, 99.7% values are 'NO'- which is the case with general population
# A "positive" ('YES') HBsAg test result means that the person is infected with hepatitis B. That is not the case, in general, in populations. Most people are Negative.
# Since almost all people in this dataset are also negative, we will drop this feature, as a singletone feature has no statistical significance.
# It would be ridiculous to impute the NaN values with 'NO' and claim some significance for the feature.

# %%
# dropping agHBs
data.drop(columns=['agHBs'], inplace=True)

# %%
data['chagas'].value_counts() #Of the total 48153 patients, ONLY 72 are positive for chagas
# Out:
# NO     44069
# YES       72
# Name: chagas, dtype: int64

# %%
data['chagas'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Pie Chart of chagas disease")
plt.show()
#Clearly, we need to drop this feature

# %%
data.drop(columns='chagas',inplace=True)

# %%
data.sample(12)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis     race sex  \
# 41624  49572 2009-10-07       45  Midage           6.00000   Branca   F
# 20608  26130 2011-01-31       75   Major          18.00000   Branca   M
# 44785  53128 2001-03-28       69   Major          13.00000   Branca   M
# 29828  36383 2017-12-28       41  Midage          19.00000    Negra   M
# 13798  18245 2017-04-03       70   Major          13.00000   Branca   M
# 39399  47017 2015-12-14       53  Midage          14.00000    Negra   M
# 1434    1926 2016-08-18       43  Midage          80.00000    Parda   F
# 37063  44431 2013-06-05       74   Major          18.00000  Amarela   F
# 35942  43197 2016-06-20       59  Midage          11.00000   Branca   M
# 9834   12988 2010-01-25       29  Midage          12.00000   Branca   F
# 3710    4995 2011-11-08       63   Major          56.00000    Parda   M
# 42227  50242 2014-01-16       60   Major          14.00000   Branca   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 41624             Other         1          O                   0       YES
# 20608          Diabetes         0          A                   0        NO
# 44785          Diabetes         0          A                   0        NO
# 29828             Other         1          O                   1        NO
# 13798          Diabetes         0          A                   0        NO
# 39399          Diabetes         0          A                   0        NO
# 1434              Other         1          O                   1       YES
# 37063          Diabetes         0          O                   0       YES
# 35942               HAS         1          O                   1        NO
# 9834              Other         1          A                   0        NO
# 3710           Diabetes         0          O                   0        NO
# 42227             Other         1          O                   1       YES
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 41624           2.00000               NO               0   HCFMUSP    80
# 20608           0.00000              YES               1   UNIFESP     0
# 44785           0.00000               NO               0   FUNDERP     0
# 29828           0.00000               NO               0   UNIFESP     0
# 13798           0.00000              YES               1   HCFMUSP    98
# 39399           0.00000               NO               0   HCFMUSP     0
# 1434            2.00000               NO               0   UNIFESP    31
# 37063           1.00000               NO               0   UNIFESP     0
# 35942           0.00000               NO               0   UNIFESP     0
# 9834            0.00000               NO               0   FUNDERP    72
# 3710            0.00000               NO               0   HCFMUSP     0
# 42227           3.00000               NO               0   UNIFESP     0
#
#           cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 41624  Entre_50_80      33      68      14      18        3        7
# 20608         Zero       3      31      18      39        4       13
# 44785         Zero      29      30      35      44        4        7
# 29828         Zero       3      33      35      81        3       11
# 13798     Maior_80       2      23      18      53       11       15
# 39399         Zero      23      74      15      15        7        9
# 1434    Entre_0_50       3      33      15      58       13        0
# 37063         Zero       2       0      15      35       12       15
# 35942         Zero      24      68      15      40       15       16
# 9834   Entre_50_80      29      34      40      44        4        7
# 3710          Zero      68      24      53      15       13       10
# 42227         Zero       2      25      18      27       11       16
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 41624  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 20608  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 44785  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 29828  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 13798  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 39399  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 1434     homozigoto  heterozigoto  heterozigoto                     0.25000
# 37063  heterozigoto  heterozigoto    homozigoto                     0.04000
# 35942  heterozigoto  heterozigoto  heterozigoto                     0.21000
# 9834   heterozigoto  heterozigoto  heterozigoto                     0.23000
# 3710   heterozigoto  heterozigoto  heterozigoto                     0.25000
# 42227  heterozigoto  heterozigoto  heterozigoto                     0.23000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 41624                     0.22000                    3.96000
# 20608                     0.25000                    5.75000
# 44785                     0.22000                    5.06000
# 29828                     0.23000                    4.14000
# 13798                     0.21000                    4.83000
# 39399                     0.04000                    0.88000
# 1434                      0.00000                    0.00000
# 37063                     0.21000                    0.84000
# 35942                     0.07000                    1.47000
# 9834                      0.22000                    5.06000
# 3710                      0.05000                    1.25000
# 42227                     0.07000                    1.61000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 41624                    0.10000                    0.09000
# 20608                    0.09000                    0.06000
# 44785                    0.21000                    0.20000
# 29828                    0.21000                    0.02000
# 13798                    0.09000                    0.06000
# 39399                    0.19000                    0.19000
# 1434                     0.19000                    0.07000
# 37063                    0.19000                    0.21000
# 35942                    0.19000                    0.09000
# 9834                     0.09000                    0.20000
# 3710                     0.06000                    0.19000
# 42227                    0.09000                    0.04000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 41624                   0.90000                    0.07000
# 20608                   0.54000                    0.18000
# 44785                   4.20000                    0.08000
# 29828                   0.42000                    0.18000
# 13798                   0.54000                    0.42000
# 39399                   3.61000                    0.11000
# 1434                    1.33000                    0.18000
# 37063                   3.99000                    0.42000
# 35942                   1.71000                    0.16000
# 9834                    1.80000                    0.08000
# 3710                    1.14000                    0.13000
# 42227                   0.36000                    0.42000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f HBC_antibody  \
# 41624                    0.13000                   0.91000           NO
# 20608                    0.08000                   1.44000           NO
# 44785                    0.13000                   1.04000           NO
# 29828                    0.07000                   1.26000           NO
# 13798                    0.11000                   4.62000           NO
# 39399                    0.04000                   0.44000           NO
# 1434                     0.07000                   1.26000           NO
# 37063                    0.00000                   0.00000           NO
# 35942                    0.13000                   2.08000           NO
# 9834                     0.02000                   0.16000           NO
# 3710                     0.16000                   2.08000           NO
# 42227                    0.02000                   0.84000           NO
#
#       HCV_antibody patient_still_on_list  date_acutal death  Time_death  \
# 41624           NO                    NO        43307    NO         107
# 20608           NO                    NO        43307   YES          34
# 44785           NO                    NO        43307   YES          76
# 29828           NO                   YES        43307    NO           7
# 13798           NO                    NO        43307   YES           5
# 39399           NO                    NO        43307    NO          32
# 1434            NO                   YES        43307    NO          24
# 37063           NO                    NO        43307   YES          56
# 35942           NO                   YES        43307    NO          26
# 9834            NO                    NO        43307    NO         103
# 3710            NO                    NO        43307    NO          82
# 42227           NO                   YES        43307    NO          55
#
#         Transplant Transplant_Y_N  X36MthsTx  Time_Tx priorization  \
# 41624           NO             NO          0 97.53000           NO
# 20608  Óbito Lista             NO          0 12.17000           NO
# 44785          YES            YES          0 41.17000           NO
# 29828           NO             NO          0  7.00000           NO
# 13798  Óbito Lista             NO          0  4.53000           NO
# 39399           NO             NO          0 22.60000           NO
# 1434            NO             NO          0 23.57000           NO
# 37063  Óbito Lista             NO          0 55.73000           NO
# 35942           NO             NO          0 25.53000           NO
# 9834           YES            YES          0 38.17000           NO
# 3710            NO             NO          0 24.40000           NO
# 42227           NO             NO          0 55.07000           NO
#
#       removed_list  time  event  tissue_match  urgency_factor
# 41624          YES  2926      3       0.26000         0.83000
# 20608          YES  1014      2       0.08000         0.53000
# 44785           NO  1235      1       0.48000         0.55000
# 29828           NO   210      0       0.90000         0.96000
# 13798           NO   136      2       0.71000         0.64000
# 39399          YES   678      3       0.59000         0.09000
# 1434            NO   707      0       0.64000         0.34000
# 37063           NO  1672      2       0.21000         0.35000
# 35942           NO   766      0       0.12000         0.24000
# 9834            NO  1145      1       0.29000         0.44000
# 3710           YES   732      3       0.45000         0.65000
# 42227           NO  1652      0       0.82000         0.72000

# %%
data.isna().sum()/len(data)*100 #There are no missing values in the dataset now.
# Out:
# Id                           0.00000
# date                         0.00000
# age_rec                      0.00000
# age_cat                      0.00000
# time_on_Dialysis             0.00000
# race                         0.00000
# sex                          0.00000
# underline_disease            0.00000
# diabetes                     0.00000
# Blood_type                   0.00000
# number_transfusion           0.00000
# gestation                    0.00000
# number_gestation             0.00000
# prior_transplant             0.00000
# no_prior_trans               0.00000
# subregion                    0.00000
# cPRA                         0.00000
# cPRA_cat                     0.00000
# HLA_A1                       0.00000
# HLA_A2                       0.00000
# HLA_B1                       0.00000
# HLA_B2                       0.00000
# HLA_DR1                      0.00000
# HLA_DR2                      0.00000
# DR_00                        0.00000
# B_00                         0.00000
# A_00                         0.00000
# calculated_frequency_DR.f1   0.00000
# calculated_frequency_DR.f2   0.00000
# calculated_frequency_DR.f    0.00000
# calculated_frequency_B.f1    0.00000
# calculated_frequency_B.f2    0.00000
# calculated_frequency_B.f     0.00000
# calculated_frequency_A.f1    0.00000
# calculated_frequency_A.f2    0.00000
# calculated_frequency_A.f     0.00000
# HBC_antibody                 0.00000
# HCV_antibody                 0.00000
# patient_still_on_list        0.00000
# date_acutal                  0.00000
# death                        0.00000
# Time_death                   0.00000
# Transplant                   0.00000
# Transplant_Y_N               0.00000
# X36MthsTx                    0.00000
# Time_Tx                      0.00000
# priorization                 0.00000
# removed_list                 0.00000
# time                         0.00000
# event                        0.00000
# tissue_match                 0.00000
# urgency_factor               0.00000
# dtype: float64

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
from matplotlib import rcParams

# %%
#checking with boxplot
sns.boxplot(x = data['number_gestation'],orient = 'h',color='Grey')
plt.title("BoxCox Plot of number_gestation")
rcParams['figure.figsize'] = 10,6
plt.show()

# %%
#One extreme value (63) beyond the expected limit of 42 weeks in number_gestation. We will replace it with 42.
#the outlier
data['number_gestation'] = data['number_gestation'].replace([63.0],42.0)

# %%
data.sample(12)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis    race sex  \
# 31473  38232 2010-12-13       49  Midage          35.00000  Branca   F
# 5468    7221 2011-09-27       68   Major          12.00000   Negra   M
# 45135  53513 2010-03-08       21  Midage           5.00000   Parda   M
# 24788  30701 2016-10-10       73   Major          23.00000   Parda   M
# 4350    5795 2010-05-19       61   Major           3.00000  Branca   M
# 15307  20180 2000-06-13       26  Midage          33.00000  Branca   M
# 41867  49841 2004-08-09       54  Midage           1.00000  Branca   F
# 25571  31585 2005-10-19       47  Midage           6.00000  Branca   M
# 26826  33015 2009-06-19       66   Major           1.00000  Branca   F
# 30773  37465 2003-03-17       51  Midage           4.00000   Parda   F
# 8783   11559 2010-06-01       29  Midage           3.00000   Parda   M
# 31743  38527 2016-03-09       53  Midage          26.00000  Branca   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 31473             Other         1          A                   1        NO
# 5468           Diabetes         0          B                   0        NO
# 45135               GNC         1          B                   0        NO
# 24788          Diabetes         0          O                   0        NO
# 4350                HAS         1          B                   1        NO
# 15307               GNC         1          B                   1        NO
# 41867             Other         1          O                   0        NO
# 25571               HAS         1          A                   0        NO
# 26826               HAS         1          O                   1       YES
# 30773               HAS         1          A                   0       YES
# 8783                GNC         1          A                   0        NO
# 31743             Other         1          O                   1        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 31473           0.00000               NO               0   UNIFESP     0
# 5468            0.00000               NO               0   UNIFESP     0
# 45135           0.00000               NO               0   UNIFESP     0
# 24788           0.00000              YES               1   HCFMUSP     0
# 4350            0.00000               NO               0   HCFMUSP     0
# 15307           0.00000               NO               0   FUNDERP    10
# 41867           0.00000               NO               0   HCFMUSP    84
# 25571           0.00000               NO               0   HCFMUSP     0
# 26826           6.00000               NO               0   UNIFESP     0
# 30773           1.00000               NO               0   UNIFESP     1
# 8783            0.00000               NO               0   UNIFESP     0
# 31743           0.00000               NO               0   HCFMUSP    20
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 31473        Zero       2       3       7      35        3       14
# 5468         Zero      26      66      52      58        7       11
# 45135        Zero       1      74      18      52        4       11
# 24788        Zero      25      74      15      18        1        7
# 4350         Zero       2      68      15      44        9       16
# 15307  Entre_0_50       0       2       0      40        0       13
# 41867    Maior_80      23      24      35      58       11       13
# 25571        Zero       2      32      14      40        4        7
# 26826        Zero      24      68      18      40        4       11
# 30773  Entre_0_50       2      30       7      18        7       15
# 8783         Zero      26      32      27      35        1       13
# 31743  Entre_0_50       2      24      51      58        3        4
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 31473  heterozigoto  heterozigoto  heterozigoto                     0.18000
# 5468   heterozigoto  heterozigoto  heterozigoto                     0.22000
# 45135  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 24788  heterozigoto  heterozigoto  heterozigoto                     0.19000
# 4350   heterozigoto  heterozigoto  heterozigoto                     0.04000
# 15307    homozigoto    homozigoto    homozigoto                     0.00000
# 41867  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 25571  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 26826  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 30773  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 8783   heterozigoto  heterozigoto  heterozigoto                     0.19000
# 31743  heterozigoto  heterozigoto  heterozigoto                     0.18000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 31473                     0.07000                    1.26000
# 5468                      0.23000                    5.06000
# 45135                     0.23000                    5.29000
# 24788                     0.22000                    4.18000
# 4350                      0.07000                    0.28000
# 15307                     0.25000                    0.00000
# 41867                     0.25000                    5.75000
# 25571                     0.22000                    5.06000
# 26826                     0.23000                    5.29000
# 30773                     0.21000                    4.62000
# 8783                      0.25000                    4.75000
# 31743                     0.23000                    4.14000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 31473                    0.14000                    0.21000
# 5468                     0.04000                    0.07000
# 45135                    0.09000                    0.04000
# 24788                    0.19000                    0.09000
# 4350                     0.19000                    0.20000
# 15307                    0.00000                    0.09000
# 41867                    0.21000                    0.07000
# 25571                    0.10000                    0.09000
# 26826                    0.09000                    0.09000
# 30773                    0.14000                    0.09000
# 8783                     0.04000                    0.21000
# 31743                    0.14000                    0.07000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 31473                   2.94000                    0.42000
# 5468                    0.28000                    0.06000
# 45135                   0.36000                    0.17000
# 24788                   1.71000                    0.02000
# 4350                    3.80000                    0.42000
# 15307                   0.00000                    0.00000
# 41867                   1.47000                    0.11000
# 25571                   0.90000                    0.42000
# 26826                   0.81000                    0.16000
# 30773                   1.26000                    0.42000
# 8783                    0.84000                    0.06000
# 31743                   0.98000                    0.42000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f HBC_antibody  \
# 31473                    0.18000                   7.56000           NO
# 5468                     0.02000                   0.12000           NO
# 45135                    0.04000                   0.68000           NO
# 24788                    0.04000                   0.08000           NO
# 4350                     0.13000                   5.46000           NO
# 15307                    0.42000                   0.00000           NO
# 41867                    0.16000                   1.76000           NO
# 25571                    0.06000                   2.52000           NO
# 26826                    0.13000                   2.08000           NO
# 30773                    0.13000                   5.46000           NO
# 8783                     0.06000                   0.36000           NO
# 31743                    0.16000                   6.72000           NO
#
#       HCV_antibody patient_still_on_list  date_acutal death  Time_death  \
# 31473           NO                    NO        43307    NO          93
# 5468            NO                   YES        43307    NO          83
# 45135           NO                    NO        43307   YES          85
# 24788           NO                   YES        43307    NO          22
# 4350            NO                    NO        43307   YES          63
# 15307           NO                    NO        43307   YES          49
# 41867           NO                    NO        43307    NO         170
# 25571           NO                    NO        43307   YES          87
# 26826           NO                    NO        43307    NO         111
# 30773           NO                    NO        43307   YES          45
# 8783            NO                    NO        43307    NO          99
# 31743           NO                   YES        43307    NO          29
#
#         Transplant Transplant_Y_N  X36MthsTx   Time_Tx priorization  \
# 31473          YES            YES          1   5.67000           NO
# 5468            NO             NO          0  83.13000           NO
# 45135          YES            YES          1  17.87000           NO
# 24788           NO             NO          0  21.80000           NO
# 4350   Óbito Lista             NO          0  30.93000           NO
# 15307          YES            YES          0  44.37000           NO
# 41867           NO             NO          0 107.87000           NO
# 25571  Óbito Lista             NO          0  56.70000           NO
# 26826           NO             NO          0  46.13000           NO
# 30773          YES            YES          0  42.40000           NO
# 8783           YES            YES          1   5.23000           NO
# 31743           NO             NO          0  28.97000           NO
#
#       removed_list  time  event  tissue_match  urgency_factor
# 31473           NO   170      1       0.42000         0.33000
# 5468            NO  2494      0       0.65000         0.85000
# 45135           NO   536      1       0.31000         0.88000
# 24788           NO   654      0       0.44000         0.31000
# 4350           YES  1889      2       0.34000         1.00000
# 15307           NO  1331      1       0.72000         0.72000
# 41867          YES  3236      3       0.32000         0.20000
# 25571          YES  2604      2       0.87000         0.93000
# 26826          YES  1384      3       0.73000         0.44000
# 30773           NO  1272      1       0.96000         0.83000
# 8783            NO   157      1       0.93000         0.37000
# 31743           NO   869      0       0.16000         0.02000

# %%
# creating an empty list of features to be removed.
to_be_removed = []

# %% [markdown]
# Checking features: priorization

# %%
data['priorization'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature priorization')
plt.show()

# %% [markdown]
# ALL PRIORITIZATION VALUES WERE ALREADY REMOVED. REDUNDANT COLUMN. there is only one value 'No'. No priority was given to any of the patients.
# This feature should be removed. As it does not give us any information.

# %%
to_be_removed.append('priorization')

# %% [markdown]
# Checking features: date_acutal
# Study goes from January 1, 2000 and December 31, 2017.
# 'date_acutal' is 26-07-2018- at least 7 months after the study ended. This is the date when the reaserchers started their analysis.
# This date is of no statistical significance. Our study time period is January 1, 2000 and December 31, 2017.
# So, we will remove this feature

# %%
to_be_removed.append('date_acutal')

# %% [markdown]
# Checking features: number_prior_transplant and prior_transplant
# According to our study, (from discussions with Nephrologists) what matters is if the patient had a prior transplant. The number of prior transplants is of less significance.
# the information about if the patient had a prior transplant or not is contained in the feature 'prior_transplant'
# So we will remove 'number_prior_transplant'

# %%
to_be_removed.append('X36MthsTx')

# %%
to_be_removed.append('no_prior_trans')

# %% [markdown]
# Checking features: time and Time_Tx

# %%
sns.displot(x=data['time'],kde=True, color='Green')
plt.title('Distribution of feature: time')
plt.show()

# %%
sns.displot(x=data['Time_Tx'],kde=True, color='Red')
plt.title('Distribution of feature: Time_Tx')
plt.show()

# %% [markdown]
# both features have EXACTLY the same distribution. Even the counts are same. Only scale metric is different.
# 'time' is in days. And 'TimeTx' is in months.
# choosing the one with lower range, we will drop 'time'

# %%
to_be_removed.append('time')

# %%
data.sample(20)
# Out:
#           Id       date  age_rec age_cat  time_on_Dialysis     race sex  \
# 9897   13070 2017-01-19       35  Midage           1.00000   Branca   F
# 9774   12905 2016-12-08       55  Midage           6.00000   Branca   M
# 9000   11854 2017-09-15       48  Midage           1.00000   Branca   F
# 8741   11503 2012-06-21       62   Major          45.00000   Branca   M
# 1889    2554 2012-11-29       31  Midage           3.00000   Branca   F
# 10857  14347 2005-11-10       55  Midage          17.00000   Branca   M
# 10555  13957 2015-06-29       25  Midage          22.00000   Branca   M
# 20902  26438 2016-04-05       64   Major          24.00000   Branca   M
# 30609  37287 2002-12-09       54  Midage          24.00000   Branca   F
# 25946  32023 2017-05-12       64   Major          80.00000  Amarela   F
# 4246    5666 2001-06-11       68   Major           8.00000   Branca   M
# 22148  27823 2010-09-16       65   Major          17.00000   Branca   M
# 40072  47807 2010-11-26       33  Midage           8.00000   Branca   F
# 30678  37363 2010-10-06       46  Midage           2.00000    Parda   F
# 35253  42406 2015-06-17       53  Midage          10.00000   Branca   M
# 16724  21757 2014-03-13       50  Midage          22.00000    Negra   M
# 18315  23563 2017-01-03       27  Midage         175.00000   Branca   F
# 5618    7429 2007-08-15       55  Midage           4.00000   Branca   M
# 37110  44479 2008-10-23       45  Midage          27.00000    Negra   F
# 5533    7311 2000-01-20       48  Midage           1.00000    Parda   F
#
#       underline_disease  diabetes Blood_type  number_transfusion gestation  \
# 9897              Other         1          O                   1       YES
# 9774           Diabetes         0          B                   0        NO
# 9000              Other         1          O                   0       YES
# 8741                HAS         1          O                   0        NO
# 1889           Diabetes         0          O                   1       YES
# 10857          Diabetes         0          O                   0        NO
# 10555             Other         1          A                   1        NO
# 20902          Diabetes         0          O                   0        NO
# 30609               HAS         1          O                   0        NO
# 25946               HAS         1          A                   1       YES
# 4246           Diabetes         0          O                   0        NO
# 22148               HAS         1          A                   0        NO
# 40072          Diabetes         0         AB                   1        NO
# 30678               HAS         1          B                   0       YES
# 35253          Diabetes         0          A                   1        NO
# 16724          Diabetes         0          A                   0        NO
# 18315               GNC         1          A                   0       YES
# 5618              Other         1          A                   1        NO
# 37110               HAS         1          O                   1        NO
# 5533              Other         1          O                   0        NO
#
#        number_gestation prior_transplant  no_prior_trans subregion  cPRA  \
# 9897            2.00000               NO               0   HCFMUSP    12
# 9774            0.00000               NO               0   UNIFESP     0
# 9000            2.00000               NO               0   UNIFESP     0
# 8741            0.00000               NO               0   UNIFESP     0
# 1889            1.00000               NO               0   HCFMUSP     0
# 10857           0.00000               NO               0   UNICAMP     0
# 10555           0.00000              YES               1   FUNDERP     0
# 20902           0.00000               NO               0   UNIFESP     0
# 30609           0.00000               NO               0   UNICAMP     4
# 25946           1.00000               NO               0   FUNDERP     0
# 4246            0.00000               NO               0   UNIFESP     0
# 22148           0.00000              YES               1   UNICAMP     0
# 40072           0.00000               NO               0   FUNDERP     0
# 30678           2.00000               NO               0   UNIFESP     0
# 35253           0.00000               NO               0   FUNDERP     0
# 16724           0.00000               NO               0   UNIFESP     0
# 18315           3.00000              YES               1   UNIFESP     0
# 5618            0.00000               NO               0   UNIFESP     0
# 37110           0.00000              YES               1   HCFMUSP     0
# 5533            0.00000               NO               0   UNIFESP     0
#
#          cPRA_cat  HLA_A1  HLA_A2  HLA_B1  HLA_B2  HLA_DR1  HLA_DR2  \
# 9897   Entre_0_50      24      33      14      51        3        4
# 9774         Zero       1       2      45      57        7       11
# 9000         Zero       2      24      51       0       11       15
# 8741         Zero       2       0      18      48        9       13
# 1889         Zero      30      24      41       8        4        3
# 10857        Zero      29      33       8      42        0        8
# 10555        Zero      29      29      44      44        7        7
# 20902        Zero      23      29      41      44        7        1
# 30609  Entre_0_50       2      74       0      35        9       11
# 25946        Zero      24      24      35      46        4        8
# 4246         Zero      24      26       7      39        1        4
# 22148        Zero      24       0      15      50       13       14
# 40072        Zero       2      24      54       0        4        0
# 30678        Zero      29      66      41      44        4       11
# 35253        Zero       1      23      35      44       11       15
# 16724        Zero      24      30      15       0        3       13
# 18315        Zero       2      24      35      39        4        7
# 5618         Zero       2       0      18      39       11       14
# 37110        Zero      30      33      35      42        7        0
# 5533         Zero       3      31      51      42       15        9
#
#               DR_00          B_00          A_00  calculated_frequency_DR.f1  \
# 9897   heterozigoto  heterozigoto  heterozigoto                     0.18000
# 9774   heterozigoto  heterozigoto  heterozigoto                     0.22000
# 9000   heterozigoto    homozigoto  heterozigoto                     0.23000
# 8741   heterozigoto  heterozigoto    homozigoto                     0.04000
# 1889   heterozigoto  heterozigoto  heterozigoto                     0.23000
# 10857    homozigoto  heterozigoto  heterozigoto                     0.00000
# 10555  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 20902  heterozigoto  heterozigoto  heterozigoto                     0.22000
# 30609  heterozigoto    homozigoto  heterozigoto                     0.04000
# 25946  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 4246   heterozigoto  heterozigoto  heterozigoto                     0.19000
# 22148  heterozigoto  heterozigoto    homozigoto                     0.25000
# 40072    homozigoto    homozigoto  heterozigoto                     0.23000
# 30678  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 35253  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 16724  heterozigoto    homozigoto  heterozigoto                     0.18000
# 18315  heterozigoto  heterozigoto  heterozigoto                     0.23000
# 5618   heterozigoto  heterozigoto    homozigoto                     0.23000
# 37110    homozigoto  heterozigoto  heterozigoto                     0.22000
# 5533   heterozigoto  heterozigoto  heterozigoto                     0.21000
#
#        calculated_frequency_DR.f2  calculated_frequency_DR.f  \
# 9897                      0.23000                    4.14000
# 9774                      0.23000                    5.06000
# 9000                      0.21000                    4.83000
# 8741                      0.25000                    1.00000
# 1889                      0.18000                    4.14000
# 10857                     0.12000                    0.00000
# 10555                     0.22000                    4.84000
# 20902                     0.19000                    4.18000
# 30609                     0.23000                    0.92000
# 25946                     0.12000                    2.76000
# 4246                      0.23000                    4.37000
# 22148                     0.07000                    1.75000
# 40072                     0.00000                    0.00000
# 30678                     0.23000                    5.29000
# 35253                     0.21000                    4.83000
# 16724                     0.25000                    4.50000
# 18315                     0.22000                    5.06000
# 5618                      0.07000                    1.61000
# 37110                     0.00000                    0.00000
# 5533                      0.04000                    0.84000
#
#        calculated_frequency_B.f1  calculated_frequency_B.f2  \
# 9897                     0.10000                    0.14000
# 9774                     0.05000                    0.06000
# 9000                     0.14000                    0.00000
# 8741                     0.09000                    0.01000
# 1889                     0.02000                    0.08000
# 10857                    0.08000                    0.04000
# 10555                    0.20000                    0.20000
# 20902                    0.02000                    0.20000
# 30609                    0.00000                    0.21000
# 25946                    0.21000                    0.00000
# 4246                     0.14000                    0.06000
# 22148                    0.19000                    0.04000
# 40072                    0.00000                    0.00000
# 30678                    0.02000                    0.20000
# 35253                    0.21000                    0.20000
# 16724                    0.19000                    0.00000
# 18315                    0.21000                    0.06000
# 5618                     0.09000                    0.06000
# 37110                    0.21000                    0.04000
# 5533                     0.14000                    0.04000
#
#        calculated_frequency_B.f  calculated_frequency_A.f1  \
# 9897                    1.40000                    0.16000
# 9774                    0.30000                    0.17000
# 9000                    0.00000                    0.42000
# 8741                    0.09000                    0.42000
# 1889                    0.16000                    0.13000
# 10857                   0.32000                    0.08000
# 10555                   4.00000                    0.08000
# 20902                   0.40000                    0.11000
# 30609                   0.00000                    0.42000
# 25946                   0.00000                    0.16000
# 4246                    0.84000                    0.16000
# 22148                   0.76000                    0.16000
# 40072                   0.00000                    0.42000
# 30678                   0.40000                    0.08000
# 35253                   4.20000                    0.17000
# 16724                   0.00000                    0.16000
# 18315                   1.26000                    0.42000
# 5618                    0.54000                    0.42000
# 37110                   0.84000                    0.13000
# 5533                    0.56000                    0.18000
#
#        calculated_frequency_A.f2  calculated_frequency_A.f HBC_antibody  \
# 9897                     0.07000                   1.12000           NO
# 9774                     0.42000                   7.14000           NO
# 9000                     0.16000                   6.72000           NO
# 8741                     0.00000                   0.00000           NO
# 1889                     0.16000                   2.08000           NO
# 10857                    0.07000                   0.56000           NO
# 10555                    0.08000                   0.64000           NO
# 20902                    0.08000                   0.88000           NO
# 30609                    0.04000                   1.68000           NO
# 25946                    0.16000                   2.56000           NO
# 4246                     0.06000                   0.96000           NO
# 22148                    0.00000                   0.00000           NO
# 40072                    0.16000                   6.72000           NO
# 30678                    0.02000                   0.16000           NO
# 35253                    0.11000                   1.87000           NO
# 16724                    0.13000                   2.08000           NO
# 18315                    0.16000                   6.72000           NO
# 5618                     0.00000                   0.00000           NO
# 37110                    0.07000                   0.91000           NO
# 5533                     0.08000                   1.44000           NO
#
#       HCV_antibody patient_still_on_list  date_acutal death  Time_death  \
# 9897            NO                   YES        43307    NO          18
# 9774            NO                   YES        43307    NO          20
# 9000            NO                   YES        43307    NO          10
# 8741            NO                    NO        43307    NO          74
# 1889            NO                    NO        43307   YES           6
# 10857           NO                    NO        43307   YES          14
# 10555           NO                   YES        43307    NO          37
# 20902           NO                    NO        43307    NO          28
# 30609           NO                    NO        43307    NO         190
# 25946           NO                    NO        43307    NO          15
# 4246            NO                    NO        43307   YES          28
# 22148           NO                    NO        43307    NO          96
# 40072           NO                    NO        43307    NO          93
# 30678           NO                    NO        43307   YES          63
# 35253           NO                    NO        43307   YES           9
# 16724           NO                    NO        43307    NO          53
# 18315           NO                   YES        43307    NO          19
# 5618            NO                    NO        43307   YES          73
# 37110           NO                    NO        43307    NO         119
# 5533            NO                    NO        43307    NO         225
#
#         Transplant Transplant_Y_N  X36MthsTx  Time_Tx priorization  \
# 9897            NO             NO          0 18.43000           NO
# 9774            NO             NO          0 19.83000           NO
# 9000            NO             NO          0 10.47000           NO
# 8741           YES            YES          1 22.57000           NO
# 1889   Óbito Lista             NO          0 13.70000           NO
# 10857  Óbito Lista             NO          0 14.47000           NO
# 10555           NO             NO          0 37.43000           NO
# 20902          YES            YES          1 19.63000           NO
# 30609           NO             NO          0 84.53000           NO
# 25946          YES            YES          1  1.03000           NO
# 4246   Óbito Lista             NO          0 28.40000           NO
# 22148          YES            YES          0 49.50000           NO
# 40072           NO             NO          0 55.87000           NO
# 30678  Óbito Lista             NO          0 63.47000           NO
# 35253  Óbito Lista             NO          0  8.53000           NO
# 16724          YES            YES          1  8.07000           NO
# 18315           NO             NO          0 18.97000           NO
# 5618   Óbito Lista             NO          0 72.57000           NO
# 37110          YES            YES          1 26.93000           NO
# 5533            NO             NO          0 61.13000           NO
#
#       removed_list  time  event  tissue_match  urgency_factor
# 9897            NO   553      0       0.65000         0.94000
# 9774            NO   595      0       0.70000         0.27000
# 9000            NO   314      0       0.60000         1.00000
# 8741            NO   677      1       0.20000         0.02000
# 1889           YES   179      2       0.63000         0.67000
# 10857           NO   434      2       0.25000         0.17000
# 10555           NO  1123      0       0.83000         0.87000
# 20902           NO   589      1       0.93000         0.86000
# 30609          YES  2536      3       0.90000         0.92000
# 25946           NO    31      1       0.56000         0.93000
# 4246            NO   852      2       0.76000         0.52000
# 22148           NO  1485      1       0.42000         0.38000
# 40072          YES  1676      3       0.30000         0.31000
# 30678           NO  1904      2       0.55000         0.74000
# 35253           NO   256      2       0.72000         0.77000
# 16724           NO   242      1       0.15000         0.14000
# 18315           NO   569      0       0.05000         0.96000
# 5618            NO  2177      2       0.33000         0.19000
# 37110           NO   808      1       0.79000         0.99000
# 5533           YES  1834      3       0.74000         0.96000

# %%
data['Transplant'].value_counts()
# Out:
# NO             25289
# YES            13732
# Óbito Lista     9132
# Name: Transplant, dtype: int64

# %%
data.replace(to_replace= 'Óbito Lista' , value= 'DeathList', inplace=True)

# %%
data['Transplant'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie Chart of feature: Transplant')
plt.show()

# %% [markdown]
# Either the transplant did not happen (52.5%), or it happened (28.5%) or the patient was put on DeathList (19%)
# There is something spurious about data representation.
# Its logical that the patient definitely didn't get to be transplanted if he was dead.
# Let us check two more pie charts: that of 'death' and 'Transplant_Y_N'

# %%
data['death'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie Chart of feature: death')
plt.show()

# %% [markdown]
# 24% of people died by the end of the study but 5% of them were not put on death list- which happens in many cases. Data is consistent.
# But we are not after if a particular patient died.
# We just wanted to make sure if DeathList percent in 'Transplant' is consistent. It is.

# %%
data['Transplant_Y_N'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie Chart of feature: Transplant_Y_N')
plt.show()

# %% [markdown]
# 28.5% patients got transplanted - consistent with the values in 'Transplant' feature. and rest 71.5% didn't.
# So Transplant_Y_N already contains the information 'we need' that is in 'Transplant'.
# So we will drop 'Transplant'.

# %%
to_be_removed.append('Transplant')

# %% [markdown]
# Checking features: number_gestation and gestation | again

# %% [markdown]
# We only need to know if a woman is pregnant or not. Her present gestation status (no. of weeks) matters little when it comes to choosing someone as a potential recipient of a cadaver graft.
# This was explained by doctors. So we will remove number_gestation and keep gestation with us.
# Also number_gestation is time-variant feature, something which we have considered beyond the scope of our study.
# So, we will keep 'gestation' and remove 'number_gestation'

# %%
to_be_removed.append('number_gestation')

# %% [markdown]
# Checking features: 'removed_list' and 'patient_still_on_list', both have similar values

# %%
data['removed_list'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature: removed_list')
plt.show()

# %%
data['patient_still_on_list'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature: patient_still_on_list')
plt.show()
#clearly, they are not similar.

# %%
#similarity check
sns.countplot(x=data['removed_list'],hue=data['patient_still_on_list'])
plt.title('Countplot of feature: removed list, with hue: patient_still_on_list')
plt.show()

# %%
#Clearly, 'removed_list' contains more information than 'patient_still_on_list' and subsumes all the information that 'patient_still_on_list' has in it.
#If 'removed_list'=YES, 'patient_still_on_list' cannot be 'NO'
to_be_removed.append('patient_still_on_list')

# %% [markdown]
# Checking features: Id , moreover id not req a

# %%
to_be_removed.append('Id')

# %% [markdown]
# Checking features: HLA frequencies based on allele distribution in the population

# %% [markdown]
# "HLA frequency variables (A, B and DR) were calculated by dividing the number of times the allele of interest is observed in a population by the total number of copies of all the alleles at that genetic locus in the population.To standardize HLA antigen assignments an HLA Dictionary was used. The serological equivalents were listed as expert assigned types."
# Thus, the frequencies of various HLA antigens are dependent on the population of interest where the program of graft transplant is being held. The genetic (allele) variation in serology of HLA types of a population and thus their frequencies depend on various biological factors, and will differ from geographic region to other.
# Since, we want to make a more universal study, we decide to remove the nine features associated with 'Calculated Frequencies" which are local.

# %%
hla_frequencies= ['calculated_frequency_DR.f1', 'calculated_frequency_DR.f2','calculated_frequency_DR.f', 'calculated_frequency_B.f1',\
                  'calculated_frequency_B.f2','calculated_frequency_B.f','calculated_frequency_A.f1','calculated_frequency_A.f2',\
                  'calculated_frequency_A.f']
to_be_removed.extend(hla_frequencies)

# %% [markdown]
# Checking features: race

# %%
to_be_removed.append('race') #removed as it is a local var

# %% [markdown]
# Checking features: subregion

# %%
to_be_removed.append('subregion') #removed as it is a local var

# %% [markdown]
# Checking features: age_cat and age_rec

# %%
data['age_cat'].value_counts()
# Out:
# Midage    34752
# Major     11775
# Minor      1626
# Name: age_cat, dtype: int64

# %%
data['age_cat'].replace(to_replace= 'Midage' , value= 'From18to60', inplace=True)
data['age_cat'].replace(to_replace= 'Major' , value= 'Over60', inplace=True)
data['age_cat'].replace(to_replace= 'Minor' , value= 'Below18', inplace=True)

# %%
sns.barplot(data=data,x='age_cat', y='Time_Tx', hue='Transplant_Y_N')
plt.title('Barplot of Age Categories wrt MeanTimeToEvent')
plt.show()

# %% [markdown]
# As is clear from the above graph, average waiting time of patients below 18 is lesser than those above them, which is a direct result of our allocation criteria.
# Also a patient has a very low chance of getting transplanted if they are above 60 years of age
# So, feature values is consistent,

# %%
to_be_removed.append('age_rec')

# %% [markdown]
# Checking features cPRA_cat and cPRA
# * A Calculated Panel Reactive Antibody (CPRA) score estimates the percentage of donors whose organs you would be incompatible with

# %%
data['cPRA_cat'].value_counts()
# Out:
# Zero           34205
# Entre_0_50      7311
# Maior_80        3895
# Entre_50_80     2742
# Name: cPRA_cat, dtype: int64

# %% [markdown]
# renaming the feature values of cPRA:
# * Zero:nill_possibility
# * Entre_0_50:less_possibility
# * Entre_50_80:intermediate_possibility
# * Maior_80:high_possibility

# %%
data['cPRA_cat'].replace(to_replace= 'less_possibility' , value= 'ZeroTo50', inplace=True)
data['cPRA_cat'].replace(to_replace= 'intermediate_possibility' , value= 'From50To80', inplace=True)
data['cPRA_cat'].replace(to_replace= 'high_possibility' , value= 'Over80', inplace=True)

# %%
#Barplot of cPRA Categories wrt MeanTimeToEvent
sns.barplot(data=data,x='cPRA_cat', y='Time_Tx', hue='Transplant_Y_N')
plt.title('Barplot of cPRA Categories wrt MeanTimeToEvent')
plt.show()

# %%
to_be_removed.append('cPRA')

# %% [markdown]
# FEATURE ENGINEERING
#
# Reducing Dimensionality by removing redundant features
# *italicized text*
# We pause in our analysis and remove the features as stored in to_be_removed list. And check how far we have gone.
#
# We also save the dataset in its current state as data1. We will play with data1 in further analysis.

# %%
data1 = data.drop(columns=to_be_removed)

# %%
data1.columns
# Out:
# Index(['date', 'age_cat', 'time_on_Dialysis', 'sex', 'underline_disease',
#        'diabetes', 'Blood_type', 'number_transfusion', 'gestation',
#        'prior_transplant', 'cPRA_cat', 'HLA_A1', 'HLA_A2', 'HLA_B1', 'HLA_B2',
#        'HLA_DR1', 'HLA_DR2', 'DR_00', 'B_00', 'A_00', 'HBC_antibody',
#        'HCV_antibody', 'death', 'Time_death', 'Transplant_Y_N', 'Time_Tx',
#        'removed_list', 'event', 'tissue_match', 'urgency_factor'],
#       dtype='object')

# %%
data1.rename(columns = {'underline_disease':'underlying_disease','time_on_Dialysis':'dialysis_duration','Blood_type':'blood_gp','number_transfusion':'transfusions',\
                        'Time_Tx':'duration','Time_death':'time_death','Transplant_Y_N':'if_transplanted','sex':'gender','removed_list':'if_on_list'}, inplace=True)

# %%
data1.columns
# Out:
# Index(['date', 'age_cat', 'dialysis_duration', 'gender', 'underlying_disease',
#        'diabetes', 'blood_gp', 'transfusions', 'gestation', 'prior_transplant',
#        'cPRA_cat', 'HLA_A1', 'HLA_A2', 'HLA_B1', 'HLA_B2', 'HLA_DR1',
#        'HLA_DR2', 'DR_00', 'B_00', 'A_00', 'HBC_antibody', 'HCV_antibody',
#        'death', 'time_death', 'if_transplanted', 'duration', 'if_on_list',
#        'event', 'tissue_match', 'urgency_factor'],
#       dtype='object')

# %%
#an empty list keeping a count of features to be dropped
to_be_dropped = []

# %%
sns.displot(x=data1['dialysis_duration'],kde=True)
plt.title("Distribution Plot of Dialysis Duration")
plt.show()

# %%
#log transformation of dialysis of duration
data1['dialysis_duration'] = np.log(data1['dialysis_duration'])

# %%
sns.displot(x=data1['dialysis_duration'],kde=True)
plt.title("Dialysis Duration after log transformation")
plt.show()

# %%
sns.regplot(data=data1,x='dialysis_duration',y='duration')
plt.title("Regression plot of duration wrt dialysis_duration")
plt.show()

# %% [markdown]
# Feature Analysis: transfusions
#
# It is the number of transfusions a patient gets subjects to. Clinically transfusions are a sporadic thing and do not affect transplant outcome.
# It is not time dependent, like dialysis_duration is. We do not know when a patient might need a transfusion.
# Let us do some statiscal analysis and observe.

# %%
#transfusions and if_transplanted
sns.boxplot(data=data1,x='transfusions',y='if_transplanted',orient='h')
plt.title("BoxPlot of transfusions vs if_transplanted")
plt.show()

# %% [markdown]
# Almost the same spread and the same Median.
# But let's check with Kruskal Wallis Test (as the distribution of data is not known)

# %%
stats.kruskal(data1['transfusions'][data1['if_transplanted'] == 'YES'],\
               data1['transfusions'][data1['if_transplanted'] == 'NO'])
# Out:
# KruskalResult(statistic=0.9619207923862838, pvalue=0.3267034095459755)

# %% [markdown]
# A very high value of p and low value of F statistic shows we cannot reject the null hypothesis that the median number of transfusions is same for both groups of if_transplanted- YES and NO. We don't have sufficient proof to claim that the different transfusions values lead to statistically significant difference in the outcome of if_transplanted.
# So our suspicion was correct. Thus, we can, in fact, do away with this feature.
# We don't have to worry about waiting time(duration) as its result is conditional on if_transplanted being YES.

# %%
to_be_dropped.append('transfusions')

# %% [markdown]
# Feature Analysis: gender

# %%
ct = pd.crosstab(data1['gender'],data1['if_transplanted'])
ct.plot(kind="bar", stacked=False, rot=0, )
plt.title("Crosstab of 'gender' with 'prior_transplant'")
plt.show()

# %% [markdown]
# mean counts of if_transplanted=NO and YES, are different for different groups of gender- M and F.
# Let us make try to make a plausible conclusion with chi-2 test, with alpha=0.05

# %%
c, p, dof, expected = chi2_contingency(ct)
print(p)
# Out:
# 3.779194601761589e-09

# %% [markdown]
# p-value<0.05; so, we can reject the null hypothesis that gender and if_transplanted are independent of each other
#
# Thus, if_transplanted has some dependency on gender, implying 'gender' is a feature of importance.

# %% [markdown]
# Feature Analysis: prior_transplant

# %%
data['prior_transplant'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature Prior Transplant')
plt.show()

# %%
ct = pd.crosstab(data1['prior_transplant'],data1['if_transplanted'])
ct.plot(kind="bar", stacked=False, rot=0, )
plt.title("Crosstab of 'if_transplanted' with 'prior_transplant'")
plt.show()

# %% [markdown]
# mean counts of if_transplanted=NO and YES, are different for different groups of prior_transplant NO and YES.
#
# Let us make try to make a plausible conclusion with chi-2 test, with alpha=0.05

# %%
c, p, dof, expected = chi2_contingency(ct)
print(p)
# Out:
# 2.9770539138795677e-19

# %% [markdown]
# p-value<0.05; so, we can reject the null hypothesis that prior_transplant and if_transplanted are independent of each other
#
# Thus, if_transplanted has some dependency on prior_transplant, implying 'prior_transplant' is a feature of importance.

# %% [markdown]
# Feature Analysis: HCV_antibodies

# %%
data1['HCV_antibody'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature HCV Antibodies')
plt.show()

# %%
to_be_dropped.append('HCV_antibody')

# %% [markdown]
# Feature Analysis: HBs_antibodies

# %%
data1['HBC_antibody'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature HBs antibodies')
plt.show()

# %%
to_be_dropped.append('HBC_antibody')

# %% [markdown]
# Feature Analysis: A_00, B_00, DR_00

# %%
data1['A_00'].value_counts()
# Out:
# heterozigoto    43171
# homozigoto       4982
# Name: A_00, dtype: int64

# %% [markdown]
# Let's rename the group names in their english version

# %%
data1.replace(to_replace= 'homozigoto' , value= 'Homozygote', inplace=True)
data1.replace(to_replace= 'heterozigoto' , value= 'Heterozygote', inplace=True)

# %%
data1['A_00'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature A_00')
plt.show()

# %%
data1['B_00'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature B_00')
plt.show()

# %%
data1['DR_00'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of feature DR_00')
plt.show()

# %% [markdown]
# The ratio of homozygote and heterozygote in all three: A_00,B_00, and DR_00 is statistically significant.
#
# We don't need to perform chi-2 test to check the significance of these features because like HLA types, these are not continuous features. They are biological features and each one has its importance in deciding the outcomes.

# %% [markdown]
# Feature Analysis: 'underlying_disease' and 'diabetes'

# %%
data1['underlying_disease'].value_counts()
# Out:
# Other           16626
# HAS             13165
# Diabetes         9987
# GNC              7234
# Pielonefrite     1141
# Name: underlying_disease, dtype: int64

# %% [markdown]
# Outras : others
# HAS : it is misspelled. It should be HUS (Hemolytic uremic syndrome)
# GNC : it is misspelled. It should be GNS (Glumerulo-Nephrotic Syndrome)
# Pielonefrite : Pylonephritis (PN)
# Diabetes has a count of 9987.

# %%
data1.replace(to_replace= 'Other' , value= 'others', inplace=True)
data1.replace(to_replace= 'HAS' , value= 'HUS', inplace=True)
data1.replace(to_replace= 'Diabetes' , value= 'diabetes', inplace=True)
data1.replace(to_replace= 'GNC' , value= 'GNS', inplace=True)
data1.replace(to_replace= 'Pielonefrite' , value= 'PN', inplace=True)

# %%
ct = pd.crosstab(data1['underlying_disease'],data1['if_transplanted'])
ct.plot(kind="barh", stacked=False, rot=0, )
plt.title("Crosstab of 'if_transplanted' with 'underlying_disease'")
plt.show()

# %%
c, p, dof, expected = chi2_contingency(ct)
print(p)
# Out:
# 7.596234142186201e-126

# %% [markdown]
# p-value<0.05; so, we can reject the null hypothesis that underlying_disease and if_transplanted are independent of each other
#
# Thus, if_transplanted has some dependency on underlying_disease, implying 'underlying_disease' is a feature of importance.
#
# LET US CHECK 'diabetes' feature now.

# %%
data1['diabetes'].value_counts()
# Out:
# 1    38166
# 0     9987
# Name: diabetes, dtype: int64

# %% [markdown]
# As we noted 9987 is the number in 'underlying disease' as well. But here is encoded a little unusually, maybe because of some error on the researchers part. 1 should be non-diabetic and 0 should be diabetic.
# Anyhow, the most important thing is the information of diabetes is already contained in the feature 'underlying_disease', so we can drop the feature 'diabetes' without loss of information.

# %%
to_be_dropped.append('diabetes')

# %% [markdown]
# Feature Analysis: 'date'
#
# date feature is redundant. There is already a column which contains the information of duration - one of the predictions. We have the data of each patient's stay in the study.
#
# We will drop 'date'

# %%
to_be_dropped.append('date')

# %% [markdown]
# Feature Analysis: 'death','time_death','if_on_list', and 'event'
#
# 'death','time_death','if_on_list', and 'event' are outcomes we do not care about in our analysis.
# we are after each patient's tranplants journey, in the form of their waiting time, the outcome of their wait and the variables affecting the outcome.
# so, from the perspective of this study, we can drop features related to death, and other associated events as the feature 'event' imbibes into itself.

# %%
#dropping 'death','time_death','if_on_list','event'
drop = ['death','time_death','if_on_list','event']
to_be_dropped.extend(drop)

# %% [markdown]
# PAUSE

# %%
# dropping the features
data2 = data1.drop(columns=to_be_dropped)

# %% [markdown]
# A LOOK AT PREDICTIONS
#
# We are after
#
# if_transplanted
# duration = First we check if the patient got transplanted, then we calculate their waiting time.
# So we have to depend to Time to Event methods popularly known as SURVIVAL ANALYSIS methods as explained earlier.
#
# Let us continue with our Data exploration and Preparation, now even with Kaplan Meier plots.
# For that we need to Label Encode if_transplanted

# %%
# label encoding 'if_transplanted'
le = LabelEncoder()
data2['if_transplanted'] = le.fit_transform(data2['if_transplanted'])

# %%
# prediction variable
data2['if_transplanted'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('The Predictions in terms of if_transplanted')
plt.show()

# %% [markdown]
# data is highly imbalanced in favor of 'NO'/0
# Most of the patients did not get transplanted, which is clinically expected

# %%
sns.displot(x=data2['duration'],kde=True)
plt.title("Distribution Plot of Duration")
plt.show()

# %% [markdown]
# Of those that get transplanted, a high number of them get transplanted within 12.5 months

# %% [markdown]
# Of those that get transplanted, a high number of them get transplanted within 12.5 months
#
# EDA WITH KAPLAN MEIER PLOTS
#
# A General KM Plot

# %%
kmf = KaplanMeierFitter()

# %%
kmf.fit(durations = data2['duration'], event_observed = data2['if_transplanted'])
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 48153 total observations, 34421 right-censored observations>

# %%
kmf.plot_survival_function(figsize = (10,8))
plt.xlabel("Duration in months from date of registration")
plt.ylabel("Survival Function / Probability of getting transplanted after t=t")
plt.title("Kaplan Meier Plot of the entire dataset")
plt.show()

# %% [markdown]
# the general suvival function plot as per KM estimate is as expected, it is exponential, but with a high degree of linearity.
# let us check the probability density curve (cummulative probability)

# %%
kmf.median_survival_time_
# Out:
# 92.3

# %% [markdown]
# In general, a person is expected get transplanted after 92.3 months.

# %%
kmf.plot_cumulative_density(figsize=(10,8))
plt.xlabel("Duration in months from date of registration")
plt.ylabel("Cummulative Probability of getting transplanted at t=t")
plt.title('Cumulative Probability Density Plot of Survival Curve (General)')
plt.show()

# %% [markdown]
# KM Plots with groups
#
# Hazard function is nothing but the slope of survival curve. One of the basic assumptions of CPH is that the hazard ratio (ratio of various hazards) should be constant over time. That is one of the things we are checking by plotting KM plots.
# we plot cummulative density curves of survival functions with various features to understand how much variation is there in terms of group differences.
# if there is too much difference, we may either take the different branches different features, or we may compress our period of study
# the idea is simple, the plots of various groups in a features should be approximately parallel to each other and not cut each other by a wide margin.
# We go feature by feature
#
# Feature Analysis: blood_gp
#
# Blood group is one of the most selection criteria when it comes to selecting a patient for transplant.
# But it's mostly a matter of luck, when it comes to cadaveric grafts. And yet, we can take for granted that the blood group availability depends on Population.

# %%
data2['blood_gp'].value_counts()
# Out:
# O     23640
# A     16951
# B      5834
# AB     1728
# Name: blood_gp, dtype: int64

# %% [markdown]
# We already see that the dataset of blood groups is highly favoring the group values O and A. So our model is going to be affected by that. And yet, this is the data we have, and we have to accept it as it is.
# Let us see the impact of blood groups on 'if_transplanted' with chi-2 test

# %%
ct = pd.crosstab(data2['blood_gp'],data2['if_transplanted'])
ct.plot(kind="barh", stacked=False, rot=0, )
plt.title("Crosstab of 'if_transplanted' with 'Blood Group'")
plt.show()

# %% [markdown]
# means vary depending on group

# %%
c, p, dof, expected = chi2_contingency(ct)
print(p)
# Out:
# 2.8334400233036852e-61

# %% [markdown]
# A p-value less than 0.05 and the graph clearly confirms that blood group of a patient has statistical impact on if_transplanted.
#
# Let us plot KM CDF curves for different blood groups

# %%
fig,ax = plt.subplots()

kmf.fit(durations = data2[data2['blood_gp']=='O']['duration'],
        event_observed = data2[data2['blood_gp']=='O']['if_transplanted'],
        label='Blood Group O')
kmf.plot_cumulative_density(figsize=(10,8), ax = ax) #subplot of Blood Group O

kmf.fit(durations = data2[data2['blood_gp']=='A']['duration'],
        event_observed = data2[data2['blood_gp']=='A']['if_transplanted'],
        label='Blood Group A')
kmf.plot_cumulative_density(figsize=(10,8), ax = ax)

kmf.fit(durations = data2[data2['blood_gp']=='B']['duration'],
        event_observed = data2[data2['blood_gp']=='B']['if_transplanted'],
        label='Blood Group B')
kmf.plot_cumulative_density(figsize=(10,8), ax = ax)

kmf.fit(durations = data2[data2['blood_gp']=='AB']['duration'],
        event_observed = data2[data2['blood_gp']=='AB']['if_transplanted'],
        label='Blood Group AB')
kmf.plot_cumulative_density(figsize=(10,8), ax = ax)

plt.xlabel("Duration in months from date of registration")
plt.ylabel("Cummulative Probability of getting transplanted at t=t")
plt.title('Cumulative Probability Density Plot of Survival Curve for different blood groups')
plt.show()

# %% [markdown]
# As expected, the probability of getting transplanted is generally on a higher level with blood grou AB, as it is a Universal Recipient.
# And the the same is lowest for O for all time points.
# For high values of t, the curves of different groups cross, but mostly they are parallel to each other.
# So we can go ahead with CPH modelling
#
#
# Feature Analysis: Underlying Disease

# %%
fig, ax = plt.subplots()

kmf.fit(durations = data2[data2['underlying_disease']=='diabetes']['duration'],
        event_observed = data2[data2['underlying_disease']=='diabetes']['if_transplanted'],
        label='Diabetes')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

kmf.fit(durations = data2[data2['underlying_disease']=='HUS']['duration'],
        event_observed = data2[data2['underlying_disease']=='HUS']['if_transplanted'],
        label='Hemolytic uremic syndrome')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

kmf.fit(durations = data2[data2['underlying_disease']=='GNS']['duration'],
        event_observed = data2[data2['underlying_disease']=='GNS']['if_transplanted'],
        label='Glumerulo-Nephrotic Syndrome')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

kmf.fit(durations = data2[data2['underlying_disease']=='others']['duration'],
        event_observed = data2[data2['underlying_disease']=='others']['if_transplanted'],
        label='Others')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

kmf.fit(durations = data2[data2['underlying_disease']=='PN']['duration'],
        event_observed = data2[data2['underlying_disease']=='PN']['if_transplanted'],
        label='Pylonephritis')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

plt.title("Kaplan Meir plot of different Underlying Diseases")
plt.show()

# %% [markdown]
# It is clear that the curves of various values of underlying_disease are intersecting each other. They do not have constant hazard ratios. So if we fit our dataset into CPH, we will encounter problems. (Hint: CPH assumes constant hazard ratios over time)
#
# So we can either think of dropping the feature, or better, we can convert it into different features like Others, Diabetes, Pylonephritis etc.
# That we will do in one-hot encoding.

# %% [markdown]
# Feature Analysis: gender

# %%
data2['gender'].value_counts()
# Out:
# M    28684
# F    19469
# Name: gender, dtype: int64

# %%
figure, ax = plt.subplots()

kmf.fit(durations = data2[data2['gender']=='M']['duration'],
        event_observed = data2[data2['gender']=='M']['if_transplanted'],
        label='Male')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

kmf.fit(durations = data2[data2['gender']=='F']['duration'],
        event_observed = data2[data2['gender']=='F']['if_transplanted'],
        label='Female')
kmf.plot_cumulative_density(figsize=(12,10), ax = ax)

plt.title('KM Plots of Males and Females')
plt.show()

# %% [markdown]
# parallel and with almost constant slope except for bigger values of t. we can go ahead with CPH
#
# Almost all the values are NO. We have not dropped the column because of its clinical significance.
# So we expect KM plot to be biased towards NO.
#
# PAUSE

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48153 entries, 0 to 48152
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age_cat             48153 non-null  object
#  1   dialysis_duration   48153 non-null  float64
#  2   gender              48153 non-null  object
#  3   underlying_disease  48153 non-null  object
#  4   blood_gp            48153 non-null  object
#  5   gestation           48153 non-null  object
#  6   prior_transplant    48153 non-null  object
#  7   cPRA_cat            48153 non-null  object
#  8   HLA_A1              48153 non-null  int64
#  9   HLA_A2              48153 non-null  int64
#  10  HLA_B1              48153 non-null  int64
#  11  HLA_B2              48153 non-null  int64
#  12  HLA_DR1             48153 non-null  int64
#  13  HLA_DR2             48153 non-null  int64
#  14  DR_00               48153 non-null  object
#  15  B_00                48153 non-null  object
#  16  A_00                48153 non-null  object
#  17  if_transplanted     48153 non-null  int64
#  18  duration            48153 non-null  float64
#  19  tissue_match        48153 non-null  float64
#  20  urgency_factor      48153 non-null  float64
# dtypes: float64(4), int64(7), object(10)
# memory usage: 7.7+ MB

# %% [markdown]
# ONE HOT ENCODING OF THE DATA

# %%
#creating a list of features that need to be one-hot encoded
label_encode_list = ['gender','gestation','DR_00', 'B_00', 'A_00', 'prior_transplant']
one_hot_list = ['underlying_disease', 'blood_gp', 'age_cat','cPRA_cat']

# %%
#one hot encoding
data3 = pd.get_dummies(data2,
               columns=one_hot_list,
               prefix=one_hot_list,
               drop_first=True)

# %%
#label encoding
def label_encode(data, label_encode_list):
  for feature in label_encode_list:
    data[feature] = le.fit_transform(data[feature])

# %%
label_encode(data3,label_encode_list)

# %% [markdown]
# NORMALISATION/SCALING OF DATA

# %%
scaler = MinMaxScaler(feature_range =(0, 1))
scaler.fit(data3)
# Out:
# MinMaxScaler()

# %%
data4 = pd.DataFrame(scaler.transform(data3))
data4.columns = data3.columns

# %%
data4.head()
# Out:
#    dialysis_duration  gender  gestation  prior_transplant  HLA_A1  HLA_A2  \
# 0            0.00000 1.00000    0.00000           0.00000 0.01250 0.32500
# 1            0.26696 1.00000    0.00000           0.00000 0.01250 0.30000
# 2            0.13348 1.00000    0.00000           0.00000 0.30000 0.31250
# 3            0.54559 1.00000    0.00000           1.00000 0.30000 0.31250
# 4            0.81254 1.00000    0.00000           0.00000 0.30000 0.85000
#
#    HLA_B1  HLA_B2  HLA_DR1  HLA_DR2   DR_00    B_00    A_00  if_transplanted  \
# 0 0.53659 0.62195  0.18750  0.43750 0.00000 0.00000 0.00000          0.00000
# 1 0.21951 0.42683  0.68750  0.00000 1.00000 0.00000 0.00000          0.00000
# 2 0.17073 0.21951  0.06250  0.93750 0.00000 0.00000 0.00000          0.00000
# 3 0.17073 0.21951  0.06250  0.93750 0.00000 0.00000 0.00000          0.00000
# 4 0.17073 0.32927  0.81250  0.93750 0.00000 0.00000 0.00000          0.00000
#
#    duration  tissue_match  urgency_factor  underlying_disease_HUS  \
# 0   0.05787       0.46000         0.41000                 0.00000
# 1   0.30491       0.20000         0.35000                 0.00000
# 2   0.05388       0.48000         0.95000                 1.00000
# 3   0.05388       0.41000         0.22000                 0.00000
# 4   0.02864       0.70000         0.05000                 1.00000
#
#    underlying_disease_PN  underlying_disease_diabetes  \
# 0                0.00000                      0.00000
# 1                0.00000                      1.00000
# 2                0.00000                      0.00000
# 3                0.00000                      1.00000
# 4                0.00000                      0.00000
#
#    underlying_disease_others  blood_gp_AB  blood_gp_B  blood_gp_O  \
# 0                    1.00000      0.00000     0.00000     0.00000
# 1                    0.00000      0.00000     0.00000     0.00000
# 2                    0.00000      0.00000     0.00000     1.00000
# 3                    0.00000      0.00000     0.00000     1.00000
# 4                    0.00000      0.00000     0.00000     0.00000
#
#    age_cat_From18to60  age_cat_Over60  cPRA_cat_Entre_50_80  \
# 0             0.00000         1.00000               0.00000
# 1             1.00000         0.00000               0.00000
# 2             1.00000         0.00000               1.00000
# 3             1.00000         0.00000               0.00000
# 4             0.00000         1.00000               0.00000
#
#    cPRA_cat_Maior_80  cPRA_cat_Zero
# 0            0.00000        1.00000
# 1            0.00000        1.00000
# 2            0.00000        0.00000
# 3            0.00000        0.00000
# 4            0.00000        1.00000

# %% [markdown]
# MODELLING

# %%
coxph = CoxPHFitter()

# %%
#creating a function which spurts out VIF values in the form of a dataframe

def vif(data):
  vif = pd.DataFrame()
  vif["feature"] = data.drop(columns=['if_transplanted','duration'],inplace=False).columns
  length = len(vif["feature"])
  vif["VIF"] = [variance_inflation_factor(data.values, i)
                          for i in range(length)]
  return vif

# %%
def heatmap(data):
  vif(data)
  fig,ax = plt.subplots(figsize=(30,30))
  sns.heatmap(round(data.corr().abs(),2),annot=True)
  plt.show()

# %%
coxph.fit(data4,'duration', 'if_transplanted')
coxph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 48153 total observations, 34421 right-censored observations>
#              duration col = 'duration'
#                 event col = 'if_transplanted'
#       baseline estimation = breslow
#    number of observations = 48153
# number of events observed = 13732
#    partial log-likelihood = -134207.17
#          time fit was run = 2023-11-16 03:46:57 UTC
#
# ---
#                               coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# dialysis_duration             0.37       1.45       0.04             0.29             0.45                 1.34                 1.57
# gender                        0.10       1.11       0.02             0.05             0.15                 1.05                 1.16
# gestation                     0.17       1.19       0.03             0.12             0.23                 1.12                 1.26
# prior_transplant             -0.13       0.88       0.03            -0.19            -0.07                 0.83                 0.93
# HLA_A1                       -0.36       0.70       0.06            -0.48            -0.25                 0.62                 0.78
# HLA_A2                       -0.27       0.77       0.04            -0.34            -0.20                 0.71                 0.82
# HLA_B1                       -0.34       0.71       0.05            -0.44            -0.25                 0.65                 0.78
# HLA_B2                       -0.12       0.88       0.05            -0.22            -0.02                 0.80                 0.98
# HLA_DR1                      -0.11       0.90       0.04            -0.18            -0.04                 0.84                 0.96
# HLA_DR2                       0.10       1.10       0.04             0.02             0.17                 1.03                 1.19
# DR_00                        -1.24       0.29       0.05            -1.33            -1.14                 0.26                 0.32
# B_00                         -0.40       0.67       0.04            -0.49            -0.31                 0.61                 0.73
# A_00                         -0.24       0.78       0.03            -0.31            -0.18                 0.74                 0.83
# tissue_match                 -0.03       0.97       0.03            -0.09             0.02                 0.91                 1.03
# urgency_factor               -0.02       0.98       0.03            -0.08             0.04                 0.92                 1.04
# underlying_disease_HUS       -0.22       0.80       0.03            -0.27            -0.17                 0.76                 0.84
# underlying_disease_PN        -0.18       0.83       0.06            -0.29            -0.07                 0.75                 0.93
# underlying_disease_diabetes  -0.10       0.91       0.03            -0.15            -0.04                 0.86                 0.96
# underlying_disease_others    -0.09       0.91       0.02            -0.14            -0.04                 0.87                 0.96
# blood_gp_AB                   0.22       1.24       0.04             0.13             0.30                 1.14                 1.35
# blood_gp_B                   -0.04       0.96       0.03            -0.09             0.01                 0.91                 1.01
# blood_gp_O                   -0.38       0.68       0.02            -0.42            -0.34                 0.66                 0.71
# age_cat_From18to60           -1.62       0.20       0.03            -1.69            -1.55                 0.19                 0.21
# age_cat_Over60               -2.02       0.13       0.04            -2.10            -1.94                 0.12                 0.14
# cPRA_cat_Entre_50_80         -0.29       0.75       0.05            -0.38            -0.20                 0.68                 0.82
# cPRA_cat_Maior_80            -1.26       0.28       0.06            -1.37            -1.15                 0.25                 0.32
# cPRA_cat_Zero                 0.28       1.32       0.03             0.23             0.33                 1.25                 1.39
#
#                               cmp to      z      p   -log2(p)
# covariate
# dialysis_duration               0.00   9.13 <0.005      63.60
# gender                          0.00   4.10 <0.005      14.55
# gestation                       0.00   5.94 <0.005      28.43
# prior_transplant                0.00  -4.30 <0.005      15.83
# HLA_A1                          0.00  -6.30 <0.005      31.68
# HLA_A2                          0.00  -7.22 <0.005      40.78
# HLA_B1                          0.00  -7.46 <0.005      43.42
# HLA_B2                          0.00  -2.40   0.02       5.95
# HLA_DR1                         0.00  -3.12 <0.005       9.13
# HLA_DR2                         0.00   2.62   0.01       6.85
# DR_00                           0.00 -25.54 <0.005     475.64
# B_00                            0.00  -8.87 <0.005      60.30
# A_00                            0.00  -7.62 <0.005      45.17
# tissue_match                    0.00  -1.12   0.26       1.93
# urgency_factor                  0.00  -0.75   0.45       1.15
# underlying_disease_HUS          0.00  -8.46 <0.005      55.08
# underlying_disease_PN           0.00  -3.20 <0.005       9.51
# underlying_disease_diabetes     0.00  -3.22 <0.005       9.61
# underlying_disease_others       0.00  -3.75 <0.005      12.44
# blood_gp_AB                     0.00   4.98 <0.005      20.60
# blood_gp_B                      0.00  -1.47   0.14       2.81
# blood_gp_O                      0.00 -20.12 <0.005     296.58
# age_cat_From18to60              0.00 -47.92 <0.005        inf
# age_cat_Over60                  0.00 -50.60 <0.005        inf
# cPRA_cat_Entre_50_80            0.00  -6.24 <0.005      31.07
# cPRA_cat_Maior_80               0.00 -22.57 <0.005     372.24
# cPRA_cat_Zero                   0.00  10.89 <0.005      89.35
# ---
# Concordance = 0.68
# Partial AIC = 268468.33
# log-likelihood ratio test = 5874.98 on 27 df
# -log2(p) of ll-ratio test = inf

# %% [markdown]
# CONCLUSION(S)
#
# The Team read and understood a new statistical method that is highly used in the fields of Medicine and Time Series Forecasting. The project was as much about learning as it was about application of various concepts.
#
# A lot of time and effort went in the process of Data Engineering. The team had to almost reverse engineer in order to understand the various features in the dataset. It was a new learning curve.
#
# Every feature was paid close attention to one by one, and necessary steps taken as and when required. A decent score of c-index of 0.68 was achieved.
#
# By the end it was realized that creating a full-fledged prediction model would be too demanding given the time constraints, the complexity of the project and the limitations in the understanding of team members.
#
# Inputs of the mentor helped the team in making sense of the data from an industrial perspective, and even though the scope of the project was narrowed a bit, the team considers the project a success.

# %% [markdown]
# Saving the preprocessed data

# %%
# Assuming 'data1' is your DataFrame
data1.to_csv('preprocessed_data1.csv', index=False)

# %%
from google.colab import files
files.download('preprocessed_data1.csv')

# %%
# Assuming 'data2' is your DataFrame
data2.to_csv('preprocessed_data2.csv', index=False)

# %%
from google.colab import files
files.download('preprocessed_data2.csv')

# %%
# Assuming 'data3' is your DataFrame
data3.to_csv('preprocessed_data3.csv', index=False)

# %%
from google.colab import files
files.download('preprocessed_data3.csv')

# %% [markdown]
# data4 is normalized values

# %%
# Assuming 'data4' is your DataFrame
data4.to_csv('preprocessed_data4.csv', index=False)

# %%
from google.colab import files
files.download('preprocessed_data4.csv')

# %% [markdown]
# Decision Tree Model Implementation
# using classifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Assuming you have a DataFrame 'df' with your data
df = pd.read_csv('/preprocessed_data4.csv')

# Assuming 'match' is your target variable and the rest are features
# Replace these with your actual column names
features = df.drop('prior_transplant', axis=1)
target = df['prior_transplant']

# Split the data into training and test sets
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a decision tree classifier and fit it to the training data
clf = DecisionTreeClassifier(random_state=42)
clf.fit(features_train, target_train)

# Predict the matches for the test set
target_pred = clf.predict(features_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(target_test, target_pred)
print(f"Model accuracy: {accuracy}")

# Now you can use this model to predict matches for new data
# Let's assume 'new_data' is a DataFrame containing the new donor's data
new_data = pd.DataFrame([{
    'dialysis_duration': 0.556,
    'gender': 1,
    'gestation': 0,
    'HLA_A1': 0.3,
    'HLA_A2': 0.222,
    'HLA_B1': 0.423,
    'HLA_B2': 0.243,
    'HLA_DR1': 0.02,
    'HLA_DR2': 0.78,
    'DR_00': 0,
    'B_00': 0,
    'A_00': 1,
    'if_transplanted': 0,
    'duration': 0.18,
    'tissue_match': 0.52,  # add this line, replace 'value' with actual data
    'urgency_factor': 0.9,
    'underlying_disease_HUS': 0,
    'underlying_disease_PN': 0,
    'underlying_disease_diabetes': 0,
    'underlying_disease_others': 0,
    'blood_gp_AB': 0,
    'blood_gp_B': 0,
    'blood_gp_O': 1,
    'age_cat_From18to60': 1,
    'age_cat_Over60': 0,
    'cPRA_cat_Over80': 0,
    'cPRA_cat_Zero': 1,
    'cPRA_cat_ZeroTo50': 0
}])  # replace 'value1', 'value2', etc. with actual data

predicted_match = clf.predict(new_data)
print(f"Predicted match for new donor: {predicted_match}")
# Out:
# Model accuracy: 0.81881424566504
# Predicted match for new donor: [0]

# %% [markdown]
# Given the complexity of your problem, a machine learning model that can handle non-linear relationships and interactions between features might be suitable. A Random Forest or a Gradient Boosting model could work well for this task. These models are powerful, handle a mix of categorical and numerical features, and don’t require scaling of the input features.
#
# Here’s an example of how you might set up a **Random Forest model** for this task using the sklearn library in Python:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Load your data
df = pd.read_csv('/preprocessed_data4.csv')

# Define your features and target variable
features = df.drop('tissue_match', axis=1)
target = df['tissue_match']

# Split your data into training and test sets
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a Random Forest Regressor and fit it to the training data
reg = RandomForestRegressor(random_state=42)
reg.fit(features_train, target_train)

# Predict the matches for the test set
target_pred = reg.predict(features_test)

# Calculate the RMSE of the model
rmse = mean_squared_error(target_test, target_pred, squared=False)
print(f"Model RMSE: {rmse}")

# Now you can use this model to predict matches for new data-donor data
new_data = pd.DataFrame([{
    'dialysis_duration': 0.556,
    'gender': 1,
    'gestation': 0,
    'prior_transplant': 0,
    'HLA_A1': 0.3,
    'HLA_A2': 0.222,
    'HLA_B1': 0.423,
    'HLA_B2': 0.243,
    'HLA_DR1': 0.02,
    'HLA_DR2': 0.78,
    'DR_00': 0,
    'B_00': 0,
    'A_00': 1,
    'if_transplanted': 0,
    'duration': 0.18,
    'urgency_factor': 0.9,
    'underlying_disease_HUS': 0,
    'underlying_disease_PN': 0,
    'underlying_disease_diabetes': 0,
    'underlying_disease_others': 0,
    'blood_gp_AB': 0,
    'blood_gp_B': 0,
    'blood_gp_O': 1,
    'age_cat_From18to60': 1,
    'age_cat_Over60': 0,
    'cPRA_cat_Over80': 0,
    'cPRA_cat_Zero': 1,
    'cPRA_cat_ZeroTo50': 0
}])  # replace with actual data

predicted_match = reg.predict(new_data)
print(f"Predicted match for new donor: {predicted_match}")
# Out:
# Model RMSE: 0.2915240196569812
# Predicted match for new donor: [0.5254]

# %% [markdown]
# Great job! Your Random Forest Regressor model has been trained and used to predict the 'tissue_match' for a new donor. The model's Root Mean Squared Error (RMSE) on the test set is approximately 0.292.
#
# The RMSE is a measure of the differences between the values predicted by the model and the actual values. In this case, it can be interpreted as the standard deviation of the prediction errors. A lower RMSE indicates a better fit to the data.
#
# The predicted 'tissue_match' for the new donor is 0.5254. This means that, according to your model, the tissue match score for the new donor is 0.5254. Please note that this is a prediction based on the model and the specific data you provided for the new donor. The actual outcome may vary depending on other factors not included in the model.
#
# Based on a rule of thumb, it can be said that RMSE values between 0.2 and 0.5 shows that the model can relatively predict the data accurately.

# %% [markdown]
# The predicted ‘tissue_match’ score for the new donor is 0.5254. This score is a measure of how well the donor’s kidney matches with the patient’s immune system, based on various factors such as HLA matching, blood group compatibility, and others.
#
# A higher ‘tissue_match’ score indicates a better match between the donor and the patient. The closer this score is to 1, the better the match. However, the ‘tissue_match’ score is just one factor to consider in organ allocation. Other factors such as medical urgency, waiting time, distance between donor and recipient, and others also play a crucial role.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Load your recipient data
df_recipients = pd.read_csv('/donor1.csv')

# Load your donor data
df_donor = pd.read_csv('/preprocessed_data4.csv')

# Define your features and target variable
features = df_recipients.drop('tissue_match', axis=1)
target = df_recipients['tissue_match']

# Create a Random Forest Regressor and fit it to the recipient data
reg = RandomForestRegressor(random_state=42)
reg.fit(features, target)

# Now you can use this model to predict matches for the donor
# Let's assume 'new_data' is a DataFrame containing the donor's data
new_data = df_donor.drop('tissue_match', axis=1)  # replace with actual data

predicted_matches = reg.predict(new_data)

# Add the predicted match scores to the donor data
df_donor['predicted_match'] = predicted_matches

# Sort the donors by the predicted match score
df_donor = df_donor.sort_values(by='predicted_match', ascending=False)

# Now df_donor contains the donors sorted by their predicted match score
print(df_donor)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df_donor.to_csv('/donor3.csv', index=False)

# %%
from google.colab import files
files.download('/donor3.csv')

# %%
out = pd.read_csv('/donor3.csv')

max_value = out['predicted_match'].max()
print(f"The highest value in the 'predicted_match' column is: {max_value}")
# Out:
# The highest value in the 'predicted_match' column is: 1.0
